# %% [markdown]
# # Final Project Title(TBD)

# %% [markdown]
# - Nicolas Colebank
# - Andrew Consiglio
# - Cristina De La Torre

# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.stattools import acf
from statsmodels.stats.outliers_influence import variance_inflation_factor
import scipy.stats as stats
from scipy.stats import t
# Out:
# /var/folders/60/9fnqdgyj5k1b_m74fnk4q6rw0000gn/T/ipykernel_26808/3698313885.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Abstract

# %% [markdown]
# TO DO

# %% [markdown]
# # Research Question

# %% [markdown]
# Is there a relationship between extreme weather events and climate opinions from 2018-2023 across states in the United States? Does this relationship vary in regards to state?
# <br><br>
#
# We define climate opinion to be based upon the responses of adults to the following questions:
# - Is global warming is affecting the weather?
# - Are you worried about global warming?
# - Do you support regulating CO2 as a pollutant?
# - Should my governor do more to address global warming?
# - Do you discuss global warming at least occasionally?

# %% [markdown]
# # Background (WIP)

# %% [markdown]
# > Why is this problem relevant? Or, what inspired you to investigate this problem?

# %% [markdown]
# Global warming and the effects of environmental issues at large remain relevant especially with recent patterns of natural disasters and climate change in the United States. Yet, developing effective ways with which to address the impacts of these issues remain challenging at a national scale. We want to assess this challenge by investigating possible factors that may explain the difficulty in addressing environmental issues across the country. More specifically we will be investigating these factors in relation to local extreme weather events. What are the most impactful variables when it comes to people's opinion on climate change? One that seems the most obvious is a person's personal experience. It's logical to think if someone experiences the increasing occurence of extreme weather events, their perception on climate change will shift more in the direction of climate action instead of denial. However, in this day and age where people seem to fall into echo chambers easily and maintain their opinions through confirmation bias, is perceiving enough to influence people? To find out, in this project we will analyze the correlation between extreme weather events by state and the perception of the people residing in these states.
#
# The complexity of this problem may be shaped by polarized public perception and local experiences, and so the factors we will assess will focus on local sentiment and socioeconomic elements. Analyzing sentiment such as beliefs, risk perceptions, policy support, and behaviors at a local level might lead to a richer understanding of diverse opinions. To develop larger contextual comprehension, analyzing trends of local natural disasters and environmental issues like fracking and pollution may be useful along with an investigation of local governments, their policies, and access to resources. Specifically, we'll be looking at the answers to 'does climate change affect weather?', 'are you worried about climate change?', 'should the government regulate pollutants?', 'should the governor of your state do more about climate change?', 'how often do you discuss climate change?'. We believe this range of questions encompasses someone's overall view on the climate issue, and combined, can help us tell a story about where the residents of each state fall on this complex problem.
#
# It is through an analysis of extreme weather and these factors that we would like to work towards developing effective ways to address the impact of climate change at the federal level. Hence, exploring the relationship between severe weather, public opinion, and socioeconomic disparities is particularly important because it can provide a contextual framework with which to tackle the challenge of developing effective solutions to mitigate the effects of environmental issues.
#
# Before doing further exploration, it is important to understand the subject matter: extreme weather events and climate opinion. Extreme weather events can take on many forms, but usually falls into seven categories: thunderstorms, tornadoes, floods, lightning, hail, wind, and winter weather. All have potentially catastrophic consequences depending on the severity of the event. Some events, like thunderstorms, are much more common but typically less damaging. Events like tornadoes, on the other hand, are more rare yet much more dangerous. All of these events occur in the United States, and seem to be increasing in frequency in recent years. To learn more about severe weather, visit the National Severe Storms Laboratory page [Severe Weather 101](https://www.nssl.noaa.gov/education/svrwx101/#:~:text=severe%20winter%20weather.-,Thunderstorms,floods%2C%20lightning%20and%20damaging%20winds.).
#
# There aren't specific weather events that are caused by climate change, however the severity and the frequency of all extreme weather events increases as climate change gets worse. Through research and from the data we analyze in this project, the frequency of extreme weather has been steadily increasing year over year. We're encountering hotter heat waves, longer burning wildfires, and more devastating hurricanes as a result of climate change. (https://science.nasa.gov/climate-change/extreme-weather/)
#
# On the map linked below you can see a variety of recent weather events and if they were found to have human influence. An overwhelming number of the events listed were decided to be more severe or more likely to occur due to increased CO2 output. It is widely agreed by scientists that extreme weather events are occurring more due to climate change, but we want to see if US residents agree with this sentiment, and if they believe action needs to be taken because of it.
# (https://www.carbonbrief.org/mapped-how-climate-change-affects-extreme-weather-around-the-world/)
#
# Climate opinion has become an increasingly hot topic of discussion in recent years. The effects of global warming are becoming more apparent, and with this it becomes more influential on the day-to-day life of Americans. Investigating the current climate opinion across the United States can be telling of how much climate change has had an effect on their lives currently. Although research shows the worst effects are yet to come, problems like an increasing amount of extreme weather events are pressing issues. Climate opinion can provide insight into how extreme weather events have changed stance on climate change across the USA.

# %% [markdown]
# # Hypothesis

# %% [markdown]
# There exist a relationship between recent climate opinions and extreme weather events such that as the frequency of extreme weather events increases so does negative opinions on climate.
#
# (TO DO Rationale) This is due to previously mentioned study in which __ .

# %% [markdown]
# # Data(WIP)

# %% [markdown]
# >Where did you get the data from?<br>
# >Description of the data
#
# There are a few datasets that would prove useful for making a statistical analysis to help answer this problem. For one, Yale has a dataset containing climate opinion data in the U.S. down to the county, where respondents were asked questions such as “Is climate change happening?” or questions about who should act and what policies should be implemented to affect global warming. Additionally, the National Oceanic and Atmospheric Administration (NOAA) has data on extreme weather events throughout the U.S., dating back to 1950. Harvard’s county-level dataset on U.S. Senate voting can be used to see how partisan voting influences climate change as well. All of these datasets can be downloaded as CSV files. We will use python’s pandas library to merge these datasets together, which can be done by using county name + state, which when combined is always a unique identifier. For the dataset on extreme weather events, the data can only be downloaded by type of weather event. We will pick the most common extreme weather events and use these in our main dataset.
#
#
# - Yale dataset:
#     - sample size>31000

# %% [markdown]
# ## Data Cleaning and Transformation

# %%
#for filtering out non states from event data
state_names = [
    "ALABAMA", "ALASKA", "ARIZONA", "ARKANSAS", "CALIFORNIA", "COLORADO", "CONNECTICUT",
    "DELAWARE", "FLORIDA", "GEORGIA", "HAWAII", "IDAHO", "ILLINOIS", "INDIANA", "IOWA",
    "KANSAS", "KENTUCKY", "LOUISIANA", "MAINE", "MARYLAND", "MASSACHUSETTS", "MICHIGAN",
    "MINNESOTA", "MISSISSIPPI", "MISSOURI", "MONTANA", "NEBRASKA", "NEVADA", "NEW HAMPSHIRE",
    "NEW JERSEY", "NEW MEXICO", "NEW YORK", "NORTH CAROLINA", "NORTH DAKOTA", "OHIO", "OKLAHOMA",
    "OREGON", "PENNSYLVANIA", "RHODE ISLAND", "SOUTH CAROLINA", "SOUTH DAKOTA", "TENNESSEE",
    "TEXAS", "UTAH", "VERMONT", "VIRGINIA", "WASHINGTON", "WEST VIRGINIA", "WISCONSIN", "WYOMING"
]

# %% [markdown]
# ### Climate Opinion Data

# %%
yale_climate = pd.read_csv('data/yale_climate.csv')
yale_climate.head()
# Out:
#   geotype  geoid     geoname        varname  x2010  x2011  x2012  x2013  \
# 0   state      1     Alabama  affectweather    NaN    NaN    NaN    NaN
# 1   state      2      Alaska  affectweather    NaN    NaN    NaN    NaN
# 2   state      4     Arizona  affectweather    NaN    NaN    NaN    NaN
# 3   state      5    Arkansas  affectweather    NaN    NaN    NaN    NaN
# 4   state      6  California  affectweather    NaN    NaN    NaN    NaN
#
#    x2014  x2015  x2016  x2017  x2018  x2019  x2020  x2021  x2022  x2023
# 0    NaN    NaN    NaN    NaN  52.66  49.22  53.33  53.64  49.63  50.28
# 1    NaN    NaN    NaN    NaN  57.48  54.94  60.92  62.25  59.17  60.66
# 2    NaN    NaN    NaN    NaN  60.32  58.40  63.55  64.22  61.73  63.12
# 3    NaN    NaN    NaN    NaN  53.17  50.78  55.72  55.89  51.26  52.43
# 4    NaN    NaN    NaN    NaN  67.21  64.51  69.28  70.14  67.47  68.39

# %%
yale_climate = yale_climate[yale_climate['geotype'] == 'state']
yale_climate = yale_climate[['geoname','varname', 'x2018', 'x2019', 'x2020', 'x2021', 'x2022', 'x2023']]

#consistent state names across both datasets
yale_climate['geoname'] = yale_climate['geoname'].str.upper() 
yale_climate.head()
# Out:
#       geoname        varname  x2018  x2019  x2020  x2021  x2022  x2023
# 0     ALABAMA  affectweather  52.66  49.22  53.33  53.64  49.63  50.28
# 1      ALASKA  affectweather  57.48  54.94  60.92  62.25  59.17  60.66
# 2     ARIZONA  affectweather  60.32  58.40  63.55  64.22  61.73  63.12
# 3    ARKANSAS  affectweather  53.17  50.78  55.72  55.89  51.26  52.43
# 4  CALIFORNIA  affectweather  67.21  64.51  69.28  70.14  67.47  68.39

# %%
melted = pd.melt(yale_climate, id_vars=['geoname', 'varname'], var_name='year', value_name='percentage')
melted['year'] = melted['year'].str.replace('x','').astype(int)
yale_climate = melted
yale_climate.head()
# Out:
#       geoname        varname  year  percentage
# 0     ALABAMA  affectweather  2018       52.66
# 1      ALASKA  affectweather  2018       57.48
# 2     ARIZONA  affectweather  2018       60.32
# 3    ARKANSAS  affectweather  2018       53.17
# 4  CALIFORNIA  affectweather  2018       67.21

# %% [markdown]
# <br></br>

# %% [markdown]
# ### Storm Data

# %%
df = pd.read_csv('data/storm_dataset2023.csv')
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202310         25         230         202310       27       551
# 1           202310         25         230         202310       27      1437
# 2           202310         25         230         202310       27      1126
# 3           202310         25         230         202310       27      1301
# 4           202310         25         230         202310       27       600
#
#    EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0      186682   1145781  NORTH DAKOTA          38  ...        NaN         NaN
# 1      186682   1145783  NORTH DAKOTA          38  ...        NaN         NaN
# 2      186682   1145784  NORTH DAKOTA          38  ...        NaN         NaN
# 3      186682   1145796  NORTH DAKOTA          38  ...        NaN         NaN
# 4      186682   1145884  NORTH DAKOTA          38  ...        NaN         NaN
#
#   END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT END_LON  \
# 0          NaN       NaN        NaN     NaN     NaN
# 1          NaN       NaN        NaN     NaN     NaN
# 2          NaN       NaN        NaN     NaN     NaN
# 3          NaN       NaN        NaN     NaN     NaN
# 4          NaN       NaN        NaN     NaN     NaN
#
#                                    EPISODE_NARRATIVE  \
# 0  In late October, a winter storm dumped heavy s...
# 1  In late October, a winter storm dumped heavy s...
# 2  In late October, a winter storm dumped heavy s...
# 3  In late October, a winter storm dumped heavy s...
# 4  In late October, a winter storm dumped heavy s...
#
#                                      EVENT_NARRATIVE DATA_SOURCE
# 0  Public reports 7.5 inches at Black Tiger Bay C...         CSV
# 1  Local Police Department relays storm total sno...         CSV
# 2  Public reports 10 inches of storm total snowfa...         CSV
# 3  Emergency Manager reports 6 inches of storm to...         CSV
# 4  CoCoRaHS Station ND-GF-23 reports 8.8 inches o...         CSV
#
# [5 rows x 51 columns]

# %%
df = pd.read_csv(f'data/storm_dataset{2023}.csv')
     #filters out non states
df = df[df['STATE'].isin(state_names)] 
    #there are multiple events for the same episode, this removes them
unique = df.drop_duplicates(subset=['STATE_FIPS', 'EPISODE_ID']) 
agg_funcs = {
    'EVENT_ID': 'count',
    'YEAR': 'first',
}
by_state = unique.groupby('STATE').agg(agg_funcs).reset_index()
by_state = by_state.rename({'EVENT_ID': 'COUNT'}, axis=1)
     #only columns we might use
events = unique[['STATE', 'EVENT_TYPE', 'YEAR', 'EPISODE_ID', 'EPISODE_NARRATIVE',  'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT', 'DEATHS_INDIRECT']]
events
# Out:
#                STATE         EVENT_TYPE  YEAR  EPISODE_ID  \
# 0       NORTH DAKOTA         Heavy Snow  2023      186682
# 6        MISSISSIPPI  Thunderstorm Wind  2023      180848
# 7          MINNESOTA            Drought  2023      186724
# 9           ILLINOIS  Thunderstorm Wind  2023      184619
# 11          VIRGINIA  Thunderstorm Wind  2023      185704
# ...              ...                ...   ...         ...
# 74851          TEXAS  Thunderstorm Wind  2023      186385
# 74858  NEW HAMPSHIRE        Flash Flood  2023      184741
# 74863          TEXAS           Wildfire  2023      185514
# 74864          TEXAS           Wildfire  2023      185515
# 74898        WYOMING               Hail  2023      184461
#
#                                        EPISODE_NARRATIVE  INJURIES_DIRECT  \
# 0      In late October, a winter storm dumped heavy s...                0
# 6      In the afternoon and evening of the 24th, clus...                0
# 7      D2 Drought continued from September into early...                0
# 9      A vigorous short-wave trough interacted with a...                0
# 11     Scattered severe thunderstorms in advance of a...                0
# ...                                                  ...              ...
# 74851  Thunderstorms developed along a cold front as ...                0
# 74858  An area of low pressure moved northeast from M...                0
# 74863  While weather conditions were pretty tame, we ...                0
# 74864  Hot conditions continued for the eastern Panha...                0
# 74898  An isolated thunderstorm produced quarter size...                0
#
#        INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT
# 0                      0              0                0
# 6                      0              0                0
# 7                      0              0                0
# 9                      0              0                0
# 11                     0              0                0
# ...                  ...            ...              ...
# 74851                  0              0                0
# 74858                  0              0                0
# 74863                  0              0                0
# 74864                  0              0                0
# 74898                  0              0                0
#
# [9390 rows x 9 columns]

# %%
event_dfs = []
by_state_dfs = []
def load_storm(year):
    df = pd.read_csv(f'data/storm_dataset{year}.csv')
     #filters out non states
    df = df[df['STATE'].isin(state_names)] 
    #there are multiple events for the same episode, this removes them
    unique = df.drop_duplicates(subset=['STATE_FIPS', 'EPISODE_ID']) 
    agg_funcs = {
        'EVENT_ID': 'count',
        'YEAR': 'first',
    }
    by_state = unique.groupby('STATE').agg(agg_funcs).reset_index()
    by_state = by_state.rename({'EVENT_ID': 'COUNT'}, axis=1)
     #only columns we might use
    events = unique[['STATE', 'EVENT_TYPE', 'YEAR', 'EPISODE_ID', 'EPISODE_NARRATIVE',  'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT', 'DEATHS_INDIRECT']]
    event_dfs.append(events)
    by_state_dfs.append(by_state)

# %%
years = [2018 + i for i in range(6)]
for year in years:
    load_storm(year)

# %%
#note: some 'states' on here are not actual states (like Lake Superior) - we will ignore these for now
events_df = pd.concat(event_dfs, axis=0)
event_count_df = pd.concat(by_state_dfs, axis=0)
event_count_df
# Out:
#             STATE  COUNT  YEAR
# 0         ALABAMA    149  2018
# 1          ALASKA     68  2018
# 2         ARIZONA    277  2018
# 3        ARKANSAS    191  2018
# 4      CALIFORNIA    337  2018
# ..            ...    ...   ...
# 45       VIRGINIA    212  2023
# 46     WASHINGTON    107  2023
# 47  WEST VIRGINIA    131  2023
# 48      WISCONSIN    211  2023
# 49        WYOMING    235  2023
#
# [300 rows x 3 columns]

# %%
events_df_merged = events_df.merge(yale_climate, how='inner', left_on=['STATE', 'YEAR'], right_on=['geoname','year'])

#data for each event type along with yale climate data
events_df_merged = events_df_merged.drop(columns=['geoname', 'year'])

# %%
event_count_merged = event_count_df.merge(yale_climate, how='inner', left_on=['STATE', 'YEAR'], right_on=['geoname', 'year'])

#data with number of events for each year along with the yale climate data
event_count_merged = event_count_merged.drop(columns=['geoname', 'year'])

# %% [markdown]
# ### Missingness

# %% [markdown]
# Lets start by looking at the amount of null values per column:

# %%
event_count_merged.isnull().sum()
# Out:
# STATE            0
# COUNT            0
# YEAR             0
# varname          0
# percentage    3700
# dtype: int64

# %%
events_df_merged.isnull().sum()
# Out:
# STATE                     0
# EVENT_TYPE                0
# YEAR                      0
# EPISODE_ID                0
# EPISODE_NARRATIVE         0
# INJURIES_DIRECT           0
# INJURIES_INDIRECT         0
# DEATHS_DIRECT             0
# DEATHS_INDIRECT           0
# varname                   0
# percentage           683607
# dtype: int64

# %% [markdown]
# For both of the DataFrames in question, there are no null values from the extreme weather event data (at least for the columns of interest). However, there are many null values in the 'percentage' column, suggesting that there are null values from the Yale Climate dataset.
#
# Lets see what the rows with the null values look like:

# %%
event_count_merged[event_count_merged['percentage'].isnull()]['varname'].unique()
# Out:
# array(['expOppose', 'generaterenewable', 'generaterenewableOppose',
#        'gwvoteimp', 'gwvoteimpOppose', 'president', 'presidentOppose',
#        'priority', 'priorityOppose', 'prioritycleanenergy',
#        'prioritycleanenergyOppose', 'taxdividend', 'taxdividendOppose',
#        'trustclimscisst', 'trustclimscisstOppose', 'prienv',
#        'prienvOppose', 'important', 'co2limits', 'co2limitsOppose',
#        'supportrps', 'supportrpsOppose'], dtype=object)

# %% [markdown]
# These null values look to be tied to specific questions. Depending on what questions are investigated, this could prove to be an issue.

# %% [markdown]
# The questions we want to investigate, as mentioned in our research question, are as follows:
# - Is global warming is affecting the weather?
# - Are you worried about global warming?
# - Do you support regulating CO2 as a pollutant?
# - Should my governor be doing more to address global warming?
# - Do you discuss global warming at least occasionally?
# > **note:**  Questions are mapped to variable names. See the Metadata sheet in the file data/YCOM7_publicdata.xlsx for more information.
#
# <br><br>
# Lets filter the dataframes so that only these questions are in the dataset:

# %%
research_questions = ['affectweather', 'worried', 'regulate', 'governor', 'discuss'] 

#filter by varname of questions
events_df_merged = events_df_merged[events_df_merged['varname'].isin(research_questions)]
event_count_merged = event_count_merged[event_count_merged['varname'].isin(research_questions)]

# %%
events_df_merged.isnull().sum()
# Out:
# STATE                0
# EVENT_TYPE           0
# YEAR                 0
# EPISODE_ID           0
# EPISODE_NARRATIVE    0
# INJURIES_DIRECT      0
# INJURIES_INDIRECT    0
# DEATHS_DIRECT        0
# DEATHS_INDIRECT      0
# varname              0
# percentage           0
# dtype: int64

# %%
event_count_merged.isnull().sum()
# Out:
# STATE         0
# COUNT         0
# YEAR          0
# varname       0
# percentage    0
# dtype: int64

# %% [markdown]
# As we can see from the output of the previous two cells, there is no missing data after we filter for the questions of interest. This means that no methods such as mean imputation are necessary to deal with missing data.

# %% [markdown]
# # EDA

# %% [markdown]
# ### Most common weather events by state:
#
# Some states naturally have more extreme weather events because of their geographical location. By analyzing which weather events are most prevalent in each state and matching it with our research on what events are most driven by climate change, we can select the best states to single out when we do our hypothesis testing.

# %%
#For each state, here are the counts of each type of weather event
event_counts = events_df.groupby(['STATE', 'EVENT_TYPE']).size().reset_index(name='counts')
event_counts
# Out:
#         STATE         EVENT_TYPE  counts
# 0     ALABAMA      Coastal Flood       1
# 1     ALABAMA    Cold/Wind Chill       5
# 2     ALABAMA            Drought      45
# 3     ALABAMA     Excessive Heat      11
# 4     ALABAMA        Flash Flood      89
# ...       ...                ...     ...
# 1243  WYOMING  Thunderstorm Wind     198
# 1244  WYOMING            Tornado      20
# 1245  WYOMING           Wildfire      22
# 1246  WYOMING       Winter Storm     176
# 1247  WYOMING     Winter Weather      91
#
# [1248 rows x 3 columns]

# %%
#Now just the most common weather event for each state
most_common_events = event_counts.loc[event_counts.groupby('STATE')['counts'].idxmax()]
most_common_events
# Out:
#                STATE         EVENT_TYPE  counts
# 20           ALABAMA  Thunderstorm Wind     393
# 39            ALASKA          High Wind     149
# 57           ARIZONA        Flash Flood     308
# 89          ARKANSAS  Thunderstorm Wind     295
# 118       CALIFORNIA          High Wind     477
# 147         COLORADO               Hail     378
# 177      CONNECTICUT  Thunderstorm Wind     114
# 196         DELAWARE  Thunderstorm Wind      70
# 221          FLORIDA  Thunderstorm Wind     514
# 248          GEORGIA  Thunderstorm Wind     537
# 264           HAWAII          High Surf     178
# 291            IDAHO         Heavy Snow     154
# 326         ILLINOIS  Thunderstorm Wind     361
# 353          INDIANA  Thunderstorm Wind     349
# 369             IOWA               Hail     235
# 392           KANSAS               Hail     534
# 425         KENTUCKY  Thunderstorm Wind     346
# 450        LOUISIANA  Thunderstorm Wind     248
# 475            MAINE  Thunderstorm Wind      84
# 499         MARYLAND  Thunderstorm Wind     317
# 520    MASSACHUSETTS  Thunderstorm Wind     102
# 546         MICHIGAN  Thunderstorm Wind     275
# 561        MINNESOTA               Hail     325
# 597      MISSISSIPPI  Thunderstorm Wind     302
# 623         MISSOURI  Thunderstorm Wind     331
# 645          MONTANA          High Wind     344
# 664         NEBRASKA               Hail     500
# 694           NEVADA          High Wind     221
# 719    NEW HAMPSHIRE  Thunderstorm Wind      55
# 741       NEW JERSEY  Thunderstorm Wind     172
# 761       NEW MEXICO          High Wind     286
# 794         NEW YORK  Thunderstorm Wind     426
# 821   NORTH CAROLINA  Thunderstorm Wind     630
# 840     NORTH DAKOTA               Hail     220
# 867             OHIO  Thunderstorm Wind     404
# 887         OKLAHOMA  Thunderstorm Wind     301
# 920           OREGON           Wildfire     160
# 944     PENNSYLVANIA  Thunderstorm Wind     497
# 959     RHODE ISLAND        Strong Wind      26
# 983   SOUTH CAROLINA  Thunderstorm Wind     436
# 1003    SOUTH DAKOTA               Hail     700
# 1034       TENNESSEE  Thunderstorm Wind     396
# 1065           TEXAS  Thunderstorm Wind     802
# 1085            UTAH          High Wind      86
# 1110         VERMONT  Thunderstorm Wind      76
# 1135        VIRGINIA  Thunderstorm Wind     599
# 1161      WASHINGTON         Heavy Snow     210
# 1193   WEST VIRGINIA  Thunderstorm Wind     266
# 1208       WISCONSIN               Hail     234
# 1240         WYOMING          High Wind     460

# %% [markdown]
# ### Change in events:
# Let's also look at how the number of weather events has changed over time in each state. We'll look at the averages for the first 2 years (2018/2019) vs last 2 years (2022/2023) of our data. While the scope may be small, it gives us some sort of idea of how weather events have been changing by state the past few years.

# %%
#Averages of first 2 years
event_years_first = event_count_df[event_count_df['YEAR'].isin([2018, 2019])]
event_years_first = event_years_first.groupby('STATE')['COUNT'].mean().reset_index()
event_years_first
# Out:
#              STATE  COUNT
# 0          ALABAMA  153.0
# 1           ALASKA   72.0
# 2          ARIZONA  245.0
# 3         ARKANSAS  188.5
# 4       CALIFORNIA  376.5
# 5         COLORADO  358.5
# 6      CONNECTICUT   82.5
# 7         DELAWARE   28.0
# 8          FLORIDA  260.0
# 9          GEORGIA  175.0
# 10          HAWAII  115.0
# 11           IDAHO  128.0
# 12        ILLINOIS  280.0
# 13         INDIANA  208.0
# 14            IOWA  288.5
# 15          KANSAS  299.0
# 16        KENTUCKY  224.5
# 17       LOUISIANA  132.0
# 18           MAINE   66.0
# 19        MARYLAND  177.0
# 20   MASSACHUSETTS   84.0
# 21        MICHIGAN  168.0
# 22       MINNESOTA  270.5
# 23     MISSISSIPPI  123.5
# 24        MISSOURI  241.0
# 25         MONTANA  241.5
# 26        NEBRASKA  251.0
# 27          NEVADA  108.0
# 28   NEW HAMPSHIRE   41.0
# 29      NEW JERSEY  102.0
# 30      NEW MEXICO  172.0
# 31        NEW YORK  239.5
# 32  NORTH CAROLINA  274.5
# 33    NORTH DAKOTA  109.5
# 34            OHIO  219.5
# 35        OKLAHOMA  205.5
# 36          OREGON  133.5
# 37    PENNSYLVANIA  232.5
# 38    RHODE ISLAND   23.0
# 39  SOUTH CAROLINA  150.5
# 40    SOUTH DAKOTA  402.0
# 41       TENNESSEE  183.5
# 42           TEXAS  568.5
# 43            UTAH   95.5
# 44         VERMONT   54.0
# 45        VIRGINIA  302.5
# 46      WASHINGTON  110.5
# 47   WEST VIRGINIA  182.0
# 48       WISCONSIN  219.5
# 49         WYOMING  281.0

# %%
#Averages of last 2 years
event_years_second = event_count_df[event_count_df['YEAR'].isin([2022, 2023])]
event_years_second = event_years_second.groupby('STATE')['COUNT'].mean().reset_index()
event_years_second
# Out:
#              STATE  COUNT
# 0          ALABAMA  176.5
# 1           ALASKA  135.0
# 2          ARIZONA  228.0
# 3         ARKANSAS  201.5
# 4       CALIFORNIA  388.0
# 5         COLORADO  351.5
# 6      CONNECTICUT   59.0
# 7         DELAWARE   37.5
# 8          FLORIDA  303.0
# 9          GEORGIA  184.0
# 10          HAWAII   85.0
# 11           IDAHO  139.5
# 12        ILLINOIS  220.0
# 13         INDIANA  169.0
# 14            IOWA  188.5
# 15          KANSAS  296.0
# 16        KENTUCKY  176.5
# 17       LOUISIANA  169.0
# 18           MAINE   77.0
# 19        MARYLAND  132.0
# 20   MASSACHUSETTS   62.5
# 21        MICHIGAN  135.5
# 22       MINNESOTA  254.0
# 23     MISSISSIPPI  145.0
# 24        MISSOURI  239.5
# 25         MONTANA  235.0
# 26        NEBRASKA  289.5
# 27          NEVADA  156.5
# 28   NEW HAMPSHIRE   40.5
# 29      NEW JERSEY   97.5
# 30      NEW MEXICO  192.5
# 31        NEW YORK  203.0
# 32  NORTH CAROLINA  237.5
# 33    NORTH DAKOTA  112.0
# 34            OHIO  147.0
# 35        OKLAHOMA  265.0
# 36          OREGON  137.0
# 37    PENNSYLVANIA  200.0
# 38    RHODE ISLAND   18.0
# 39  SOUTH CAROLINA  156.0
# 40    SOUTH DAKOTA  343.0
# 41       TENNESSEE  183.0
# 42           TEXAS  802.0
# 43            UTAH  116.0
# 44         VERMONT   53.0
# 45        VIRGINIA  231.0
# 46      WASHINGTON  124.5
# 47   WEST VIRGINIA  140.5
# 48       WISCONSIN  182.5
# 49         WYOMING  242.5

# %%
#Differences by state
merged_states = pd.merge(event_years_first, event_years_second, on='STATE', suffixes=('_df1', '_df2'))
merged_states['count_difference'] = merged_states['COUNT_df2'] - merged_states['COUNT_df1']
merged_states = merged_states.sort_values('count_difference', ascending=False)
merged_states
print(merged_states.iloc[:10])
# Out:
#           STATE  COUNT_df1  COUNT_df2  count_difference
# 42        TEXAS      568.5      802.0             233.5
# 1        ALASKA       72.0      135.0              63.0
# 35     OKLAHOMA      205.5      265.0              59.5
# 27       NEVADA      108.0      156.5              48.5
# 8       FLORIDA      260.0      303.0              43.0
# 26     NEBRASKA      251.0      289.5              38.5
# 17    LOUISIANA      132.0      169.0              37.0
# 0       ALABAMA      153.0      176.5              23.5
# 23  MISSISSIPPI      123.5      145.0              21.5
# 43         UTAH       95.5      116.0              20.5

# %% [markdown]
# We see the states that saw a biggest increase in events from first 2 to last 2 years were Texas, Alaska, Oklahoma, Nevada, and Florida.
# According to PolicyGenius (https://www.policygenius.com/homeowners-insurance/best-and-worst-states-for-climate-change/) the states that will fare worst in the face of climate change are Florida, Mississippi, Louisiana, Texas, and Arkansas. 4 of these states are in the top 10 of increasing weather events.\
# One thing to note is states like Texas that are larger experience more events due to their size, so it's also important to factor in percent change.

# %%
#percent_change
merged_states['percent_change'] = (merged_states['COUNT_df2'] - merged_states['COUNT_df1'])/merged_states['COUNT_df1']
merged_states = merged_states.sort_values('percent_change', ascending=False)
print(merged_states.iloc[:10])
# Out:
#           STATE  COUNT_df1  COUNT_df2  count_difference  percent_change
# 1        ALASKA       72.0      135.0              63.0        0.875000
# 27       NEVADA      108.0      156.5              48.5        0.449074
# 42        TEXAS      568.5      802.0             233.5        0.410730
# 7      DELAWARE       28.0       37.5               9.5        0.339286
# 35     OKLAHOMA      205.5      265.0              59.5        0.289538
# 17    LOUISIANA      132.0      169.0              37.0        0.280303
# 43         UTAH       95.5      116.0              20.5        0.214660
# 23  MISSISSIPPI      123.5      145.0              21.5        0.174089
# 18        MAINE       66.0       77.0              11.0        0.166667
# 8       FLORIDA      260.0      303.0              43.0        0.165385

# %% [markdown]
# ### Trends in Climate Opinions

# %% [markdown]
# Data on climate opinion from the yale 2023 dataset is broken down by percentage of responses for a question referring to their opinion on a particular statement. These questions are mapped the variable names. The breakdown for our questions is as follows:
#
# | Question  | Related `varname` |
# | :-------- |:----------------  |
# | is global warming is affecting the weather?   | `affectweather` |
# | Are you worried about global warming?  | `worried`|
# | Do you support regulating CO2 as a pollutant? |  `regulate`|
# |   Should my governor do more to address global warming?|`governor`|
# | Do you discuss global warming at least occasionally? | `discuss` |

# %% [markdown]
# This set of questions comes from five categories of opinions, our analysis of the data would benefit from investigating patterns within responses on climate opinion. Let us compare the percent distributions for each question.

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

sns.boxplot(
    events_df_merged,
    y = "varname",
    x = "percentage",
    ax = ax).set(
    title='Percent Distributions of Agreement for \nClimate Opinion Questions from 2018-2023', 
    ylabel = "Questions"
);

# %% [markdown]
# Analyzing the distribution of percentages for the responses in favor of each question it looks like the distribution for `regulate` which is the variable name corresponding to support for regulating CO2 as a pollutant has the highest maximum percentage of support in comparison to other questions. This along with about half of its distribution being high relative to the other distributions.
#
# We can also see that the percent distribution with the most spread is that of `affectweather` which corresponds responses in agreement with the statement of global warming affecting the weather. This illustrates that there are varied responses when it comes to the affects of global warming on weather, something that is worth investigating.

# %% [markdown]
#  We can also visualize the percent support for each question relative to each other with the following visualization:

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 5))

sns.barplot( 
    events_df_merged.sort_values('percentage'),
    y = 'percentage', 
    x = 'varname',
    ax = ax).set(
    title='Percent Agreement for each Climate \n Opinion Question from 2018-2023',
    xlabel = "Questions"
);

# %% [markdown]
# Relative to each other, it seems the questions with highest percent support, besides `regulate`, are `worried` and `affectweather` closely after. This shows that questions pertaining to **concern, affects, and regulation** are the most supported over defined time period. To a certain extent, this also may imply that questions that deal with beliefs, risk perceptions, and policy are the most supported types.
#
# The plot also demonstrates that `discuss` is the least supported question with a large difference between it and the next lowest percent support for a question. This variable name corresponds to the question of discussion climate change occassionally.

# %% [markdown]
# Analyzing the percent support for these questions over time might prove to be insightful of any significant change.

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 5))

sns.lineplot(
    events_df_merged, 
    x = "YEAR", 
    y = "percentage", 
    hue = "varname").set(
    title='Percent of Responses in Support of Question from 2018-2023',
    xlabel = "Year"
)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1));

# %% [markdown]
# Most of the percentages in favor of its respective question are lower more recently in comparison to 2018, with exception of `affectweather` and perhaps `worried`. These two exception also seem to follow a similar trend over the years.
#
# The most stagnant percentage support for a question is that of `discuss` which also remains the lowest support across all years. The questions that show the most variation in relation to percent support over the years are `governor`, `affectweather`, and `worried`.

# %% [markdown]
# ### Trends in Extreme Weather
# To get an overview of extreme weather, we can first analyze the frequency of each type of extreme weather relative to each other within the years of interest.

# %%
event_occur = events_df_merged.groupby(["YEAR", "EVENT_TYPE"]).agg(event_count=('STATE', 'count')).reset_index()

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 7))

sns.barplot(
    event_occur.sort_values("event_count", ascending = False), 
    y = "EVENT_TYPE", 
    x = "event_count",
    orient = "h",  
    ax = ax).set(
    title='Frequency of Extreme Weather Events from 2018-2023',
    xlabel = "count",
    ylabel = "weather event"
);

# %% [markdown]
# Although it is difficult to view the frequency of each event within the plot, it illustrates the significant difference between the frequency of `Thunderstorm Wind` in comparison to all other events.
#
# To get a better sense of the relation between the most frequent weather events besides `Thunderstorm Wind`, the distribution of the following 5 events with the highest recorded frequency are visualized below:

# %%
#filter to top occuring 
top_events = event_occur.query("event_count < 8000 and event_count > 3400")

fig, ax = plt.subplots(1, 2, figsize=(11.5, 4))
#boxplot
sns.boxplot(
    top_events.sort_values("event_count"), 
    x = "EVENT_TYPE", 
    y = "event_count",
    ax = ax[0]
).set(
    xlabel = "weather event",
    ylabel = "count"
)

#barplot
sns.barplot(
    top_events.sort_values("event_count"), 
    x = "EVENT_TYPE", 
    y = "event_count",
    ax = ax[1]
).set(
    xlabel = "weather event",
    ylabel = "count"
)

#labels and spacing
plt.subplots_adjust(wspace=0.25)
plt.suptitle('Subsequent Most Frequent Weather Events from 2018-2023');

# %% [markdown]
# It can be seen from the plot that most distributions are relatively around the same frequency of occurence except `Hail` with a frequency of large difference. `Hail` also has the most variability in comparison to the frequency of the other weather events.
#
# In a similar manner let us investigate events with the lowest recorded occurences over time.The lowest recorded occurences all have only a count of 5 and as such we will not visualize their distributions of their repsective weather events. Instead we can see that the lowest occurence, the weather event, and the year in which it was experienced can be see in the following dataframe.

# %%
event_occur.query("event_count <= 5")
# Out:
#      YEAR        EVENT_TYPE  event_count
# 31   2018       Sneakerwave            5
# 49   2019       Dense Smoke            5
# 66   2019         Hurricane            5
# 73   2019             Sleet            5
# 114  2020             Sleet            5
# 189  2022   Lakeshore Flood            5
# 200  2022  Volcanic Ashfall            5
# 234  2023  Storm Surge/Tide            5

# %% [markdown]
# From this filtered dataset we can see that the smallest frequencies were recorded for `Sneakerweave`, `Dense Smoke`, `Hurricane`, `Sleet`, `Lakeshore Flood`, `Volcanic Ashfall`, and `Storm Surge/Tide`.

# %% [markdown]
# It is important to note that these frequencies of weather events are a count in relation to each year, and in being so weather events can be more frequent in some years in comparison to other years. To get an idea of the overall most occuring and least occuring events we can analyze total counts recorded from 2018-2023.

# %%
overall_count = (event_occur
                 .groupby('EVENT_TYPE')[['event_count']]
                 .sum()
                 .sort_values('event_count', ascending = False)
                )

overall_count.head()
# Out:
#                    event_count
# EVENT_TYPE
# Thunderstorm Wind        64335
# Hail                     39180
# High Wind                21770
# Flash Flood              20370
# Flood                    16780

# %% [markdown]
# Overall, the top 5 most frequent extreme weather events reflect that of the previous plots. For the weather events with lowest occurences it can be seen that besides previously mentioned events with low frequency, overall `Tsunami` and `Seiche` are the two **least frequent**.

# %%
overall_count.tail()
# Out:
#                   event_count
# EVENT_TYPE
# Hurricane                  70
# Volcanic Ashfall           60
# Sneakerwave                55
# Seiche                     30
# Tsunami                    25

# %% [markdown]
# <br><br>
# To further understand the frequency of events, we can look at any trends over time. To do this we will look at the proportions of events per year.

# %%
totals = event_occur.groupby(["YEAR"])['event_count'].sum()

event_occur['event_prop'] = event_occur.event_count / event_occur.YEAR.apply(lambda x: totals.loc[x])

# %% [markdown]
# Reevaluating the distribution of extreme weather events as proportions, we can analyze any changes relative to type of extreme weather event from previous analysis.

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 7))

sns.barplot(
    event_occur.sort_values("event_prop", ascending = False), 
    y = "EVENT_TYPE", 
    x = "event_prop",
    orient = "h",  
    ax = ax).set(
    title='Proportion of Extreme Weather Events from 2018-2023',
    xlabel = "proportion",
    ylabel = "weather event"
);

# %% [markdown]
# `Thunderstorm Wind` still remains the event with highest occurences across the years, let us evaluate these changes over time.

# %%
# get events with highest recorded props
top_events = list(event_occur.query("event_prop > 0.07").EVENT_TYPE.unique())

#lineplot
fig, ax = plt.subplots(1, 1, figsize=(6, 5))
sns.lineplot(
    event_occur.query(f'EVENT_TYPE in {top_events}'), 
    x = "YEAR", 
    y = "event_prop", 
    hue = "EVENT_TYPE").set(
    title='Proportion of Weather Events Over Time',
    xlabel = "Year", 
    ylabel= "Proportion"
)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1));

# %% [markdown]
# From the plot, it is seen that `Drought`s, `Flash Flood`s, `Flood`s, and `High Wind` all are similar in value of proportional occurence with much overalp throughout the years. The plot also illustrates some fluctuation in `Thunderstorn Wind` which across each year reamins significantly higher than other extreme weather events.
#
# We can carry out the same analysis for events with low recorded frequencies.

# %%
#get events with lowest recorded props
bottom_events = list(event_occur.query("event_prop < 0.0001045").EVENT_TYPE.unique())

#lineplot
fig, ax = plt.subplots(1, 1, figsize=(6, 5))
sns.lineplot(
    event_occur.query(f'EVENT_TYPE in {bottom_events}'), 
    x = "YEAR", 
    y = "event_prop", 
    hue = "EVENT_TYPE").set(
    title='Proportion of Weather Events Over Time',
    xlabel = "Year",
    ylabel = "Proportion"
)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1));

# %% [markdown]
# Across years, all events except `Hurricane` all follow an upwards trend, such that their proportional occurences are higher in 2023 than in 2018. Although `Huricane` peaks sharply around 2020 implying significant change, the scale of proportions in plot is very miniscule with a change from a porportion of $0.0008$ to that of less that $0.0002$.

# %% [markdown]
# ### Most Events by State

# %%
events_most = events.groupby('STATE').size().reset_index(name='counts')
events_most = events_most.sort_values('counts', ascending = False)
events_most
# Out:
#              STATE  counts
# 42           TEXAS     878
# 4       CALIFORNIA     360
# 40    SOUTH DAKOTA     349
# 5         COLORADO     346
# 15          KANSAS     314
# 8          FLORIDA     307
# 26        NEBRASKA     302
# 35        OKLAHOMA     285
# 22       MINNESOTA     254
# 49         WYOMING     235
# 24        MISSOURI     232
# 32  NORTH CAROLINA     228
# 45        VIRGINIA     212
# 37    PENNSYLVANIA     212
# 48       WISCONSIN     211
# 25         MONTANA     211
# 12        ILLINOIS     208
# 3         ARKANSAS     202
# 14            IOWA     202
# 9          GEORGIA     199
# 17       LOUISIANA     195
# 41       TENNESSEE     190
# 0          ALABAMA     189
# 2          ARIZONA     185
# 31        NEW YORK     185
# 30      NEW MEXICO     181
# 23     MISSISSIPPI     165
# 27          NEVADA     164
# 16        KENTUCKY     151
# 39  SOUTH CAROLINA     148
# 13         INDIANA     147
# 36          OREGON     145
# 1           ALASKA     142
# 11           IDAHO     137
# 47   WEST VIRGINIA     131
# 34            OHIO     126
# 19        MARYLAND     126
# 21        MICHIGAN     115
# 43            UTAH     114
# 46      WASHINGTON     107
# 29      NEW JERSEY     103
# 33    NORTH DAKOTA      92
# 10          HAWAII      77
# 18           MAINE      73
# 20   MASSACHUSETTS      59
# 6      CONNECTICUT      51
# 44         VERMONT      49
# 7         DELAWARE      40
# 28   NEW HAMPSHIRE      39
# 38    RHODE ISLAND      17

# %%
combined_df = pd.concat([events_most.head(3), events_most.tail(3)])
combined_df['STATE'] = combined_df['STATE'].apply(lambda x: x[:7])
plt.figure(figsize=(10, 6))
combined_df.reset_index(drop=True, inplace=True)
combined_df.plot(kind='bar', x='STATE', y='counts', legend=False)
plt.xlabel('State')
plt.ylabel('Event Count')
plt.title('Bar Chart of Top 3 and Bottom 3 States By # of Events')
plt.xticks(rotation=0)
plt.show()

# %%
#Now just the most common weather event for each state
most_common_events = event_counts.loc[event_counts.groupby('STATE')['counts'].idxmax()]
most_common_events
# Out:
#                STATE         EVENT_TYPE  counts
# 20           ALABAMA  Thunderstorm Wind     393
# 39            ALASKA          High Wind     149
# 57           ARIZONA        Flash Flood     308
# 89          ARKANSAS  Thunderstorm Wind     295
# 118       CALIFORNIA          High Wind     477
# 147         COLORADO               Hail     378
# 177      CONNECTICUT  Thunderstorm Wind     114
# 196         DELAWARE  Thunderstorm Wind      70
# 221          FLORIDA  Thunderstorm Wind     514
# 248          GEORGIA  Thunderstorm Wind     537
# 264           HAWAII          High Surf     178
# 291            IDAHO         Heavy Snow     154
# 326         ILLINOIS  Thunderstorm Wind     361
# 353          INDIANA  Thunderstorm Wind     349
# 369             IOWA               Hail     235
# 392           KANSAS               Hail     534
# 425         KENTUCKY  Thunderstorm Wind     346
# 450        LOUISIANA  Thunderstorm Wind     248
# 475            MAINE  Thunderstorm Wind      84
# 499         MARYLAND  Thunderstorm Wind     317
# 520    MASSACHUSETTS  Thunderstorm Wind     102
# 546         MICHIGAN  Thunderstorm Wind     275
# 561        MINNESOTA               Hail     325
# 597      MISSISSIPPI  Thunderstorm Wind     302
# 623         MISSOURI  Thunderstorm Wind     331
# 645          MONTANA          High Wind     344
# 664         NEBRASKA               Hail     500
# 694           NEVADA          High Wind     221
# 719    NEW HAMPSHIRE  Thunderstorm Wind      55
# 741       NEW JERSEY  Thunderstorm Wind     172
# 761       NEW MEXICO          High Wind     286
# 794         NEW YORK  Thunderstorm Wind     426
# 821   NORTH CAROLINA  Thunderstorm Wind     630
# 840     NORTH DAKOTA               Hail     220
# 867             OHIO  Thunderstorm Wind     404
# 887         OKLAHOMA  Thunderstorm Wind     301
# 920           OREGON           Wildfire     160
# 944     PENNSYLVANIA  Thunderstorm Wind     497
# 959     RHODE ISLAND        Strong Wind      26
# 983   SOUTH CAROLINA  Thunderstorm Wind     436
# 1003    SOUTH DAKOTA               Hail     700
# 1034       TENNESSEE  Thunderstorm Wind     396
# 1065           TEXAS  Thunderstorm Wind     802
# 1085            UTAH          High Wind      86
# 1110         VERMONT  Thunderstorm Wind      76
# 1135        VIRGINIA  Thunderstorm Wind     599
# 1161      WASHINGTON         Heavy Snow     210
# 1193   WEST VIRGINIA  Thunderstorm Wind     266
# 1208       WISCONSIN               Hail     234
# 1240         WYOMING          High Wind     460

# %% [markdown]
# ### Change in events:
# Let's also look at how the number of weather events has changed over time in each state. We'll look at the averages for the first 2 years (2018/2019) vs last 2 years (2022/2023) of our data. While the scope may be small, it gives us some sort of idea of how weather events have been changing by state the past few years.

# %%
#Averages of first 2 years
event_years_first = event_count_df[event_count_df['YEAR'].isin([2018, 2019])]
event_years_first = event_years_first.groupby('STATE')['COUNT'].mean().reset_index()
event_years_first
# Out:
#              STATE  COUNT
# 0          ALABAMA  153.0
# 1           ALASKA   72.0
# 2          ARIZONA  245.0
# 3         ARKANSAS  188.5
# 4       CALIFORNIA  376.5
# 5         COLORADO  358.5
# 6      CONNECTICUT   82.5
# 7         DELAWARE   28.0
# 8          FLORIDA  260.0
# 9          GEORGIA  175.0
# 10          HAWAII  115.0
# 11           IDAHO  128.0
# 12        ILLINOIS  280.0
# 13         INDIANA  208.0
# 14            IOWA  288.5
# 15          KANSAS  299.0
# 16        KENTUCKY  224.5
# 17       LOUISIANA  132.0
# 18           MAINE   66.0
# 19        MARYLAND  177.0
# 20   MASSACHUSETTS   84.0
# 21        MICHIGAN  168.0
# 22       MINNESOTA  270.5
# 23     MISSISSIPPI  123.5
# 24        MISSOURI  241.0
# 25         MONTANA  241.5
# 26        NEBRASKA  251.0
# 27          NEVADA  108.0
# 28   NEW HAMPSHIRE   41.0
# 29      NEW JERSEY  102.0
# 30      NEW MEXICO  172.0
# 31        NEW YORK  239.5
# 32  NORTH CAROLINA  274.5
# 33    NORTH DAKOTA  109.5
# 34            OHIO  219.5
# 35        OKLAHOMA  205.5
# 36          OREGON  133.5
# 37    PENNSYLVANIA  232.5
# 38    RHODE ISLAND   23.0
# 39  SOUTH CAROLINA  150.5
# 40    SOUTH DAKOTA  402.0
# 41       TENNESSEE  183.5
# 42           TEXAS  568.5
# 43            UTAH   95.5
# 44         VERMONT   54.0
# 45        VIRGINIA  302.5
# 46      WASHINGTON  110.5
# 47   WEST VIRGINIA  182.0
# 48       WISCONSIN  219.5
# 49         WYOMING  281.0

# %%
#Averages of last 2 years
event_years_second = event_count_df[event_count_df['YEAR'].isin([2022, 2023])]
event_years_second = event_years_second.groupby('STATE')['COUNT'].mean().reset_index()
event_years_second
# Out:
#              STATE  COUNT
# 0          ALABAMA  176.5
# 1           ALASKA  135.0
# 2          ARIZONA  228.0
# 3         ARKANSAS  201.5
# 4       CALIFORNIA  388.0
# 5         COLORADO  351.5
# 6      CONNECTICUT   59.0
# 7         DELAWARE   37.5
# 8          FLORIDA  303.0
# 9          GEORGIA  184.0
# 10          HAWAII   85.0
# 11           IDAHO  139.5
# 12        ILLINOIS  220.0
# 13         INDIANA  169.0
# 14            IOWA  188.5
# 15          KANSAS  296.0
# 16        KENTUCKY  176.5
# 17       LOUISIANA  169.0
# 18           MAINE   77.0
# 19        MARYLAND  132.0
# 20   MASSACHUSETTS   62.5
# 21        MICHIGAN  135.5
# 22       MINNESOTA  254.0
# 23     MISSISSIPPI  145.0
# 24        MISSOURI  239.5
# 25         MONTANA  235.0
# 26        NEBRASKA  289.5
# 27          NEVADA  156.5
# 28   NEW HAMPSHIRE   40.5
# 29      NEW JERSEY   97.5
# 30      NEW MEXICO  192.5
# 31        NEW YORK  203.0
# 32  NORTH CAROLINA  237.5
# 33    NORTH DAKOTA  112.0
# 34            OHIO  147.0
# 35        OKLAHOMA  265.0
# 36          OREGON  137.0
# 37    PENNSYLVANIA  200.0
# 38    RHODE ISLAND   18.0
# 39  SOUTH CAROLINA  156.0
# 40    SOUTH DAKOTA  343.0
# 41       TENNESSEE  183.0
# 42           TEXAS  802.0
# 43            UTAH  116.0
# 44         VERMONT   53.0
# 45        VIRGINIA  231.0
# 46      WASHINGTON  124.5
# 47   WEST VIRGINIA  140.5
# 48       WISCONSIN  182.5
# 49         WYOMING  242.5

# %%
#Differences by state
merged_states = pd.merge(event_years_first, event_years_second, on='STATE', suffixes=('_df1', '_df2'))
merged_states['count_difference'] = merged_states['COUNT_df2'] - merged_states['COUNT_df1']
merged_states = merged_states.sort_values('count_difference', ascending=False)
merged_states
print(merged_states.iloc[:10])
# Out:
#           STATE  COUNT_df1  COUNT_df2  count_difference
# 42        TEXAS      568.5      802.0             233.5
# 1        ALASKA       72.0      135.0              63.0
# 35     OKLAHOMA      205.5      265.0              59.5
# 27       NEVADA      108.0      156.5              48.5
# 8       FLORIDA      260.0      303.0              43.0
# 26     NEBRASKA      251.0      289.5              38.5
# 17    LOUISIANA      132.0      169.0              37.0
# 0       ALABAMA      153.0      176.5              23.5
# 23  MISSISSIPPI      123.5      145.0              21.5
# 43         UTAH       95.5      116.0              20.5

# %% [markdown]
# We see the states that saw a biggest increase in events from first 2 to last 2 years were Texas, Alaska, Oklahoma, Nevada, and Florida.
# According to PolicyGenius (https://www.policygenius.com/homeowners-insurance/best-and-worst-states-for-climate-change/) the states that will fare worst in the face of climate change are Florida, Mississippi, Louisiana, Texas, and Arkansas. 4 of these states are in the top 10 of increasing weather events.\
# One thing to note is states like Texas that are larger experience more events due to their size, so it's also important to factor in percent change.

# %%
#percent_change
merged_states['percent_change'] = (merged_states['COUNT_df2'] - merged_states['COUNT_df1'])/merged_states['COUNT_df1']
merged_states = merged_states.sort_values('percent_change', ascending=False)
print(merged_states.iloc[:20])
# Out:
#              STATE  COUNT_df1  COUNT_df2  count_difference  percent_change
# 1           ALASKA       72.0      135.0              63.0        0.875000
# 27          NEVADA      108.0      156.5              48.5        0.449074
# 42           TEXAS      568.5      802.0             233.5        0.410730
# 7         DELAWARE       28.0       37.5               9.5        0.339286
# 35        OKLAHOMA      205.5      265.0              59.5        0.289538
# 17       LOUISIANA      132.0      169.0              37.0        0.280303
# 43            UTAH       95.5      116.0              20.5        0.214660
# 23     MISSISSIPPI      123.5      145.0              21.5        0.174089
# 18           MAINE       66.0       77.0              11.0        0.166667
# 8          FLORIDA      260.0      303.0              43.0        0.165385
# 0          ALABAMA      153.0      176.5              23.5        0.153595
# 26        NEBRASKA      251.0      289.5              38.5        0.153386
# 46      WASHINGTON      110.5      124.5              14.0        0.126697
# 30      NEW MEXICO      172.0      192.5              20.5        0.119186
# 11           IDAHO      128.0      139.5              11.5        0.089844
# 3         ARKANSAS      188.5      201.5              13.0        0.068966
# 9          GEORGIA      175.0      184.0               9.0        0.051429
# 39  SOUTH CAROLINA      150.5      156.0               5.5        0.036545
# 4       CALIFORNIA      376.5      388.0              11.5        0.030544
# 36          OREGON      133.5      137.0               3.5        0.026217

# %%
merged_states = merged_states.sort_values('count_difference', ascending=False)
combined_df_per = pd.concat([merged_states.head(3), merged_states.tail(3)])
combined_df_per['STATE'] = combined_df_per['STATE'].apply(lambda x: x[:7])
plt.figure(figsize=(10, 6))
combined_df_per.reset_index(drop=True, inplace=True)
combined_df_per.plot(kind='bar', x='STATE', y='count_difference', legend=False)
plt.xlabel('State')
plt.ylabel('Count Difference')
plt.title('Bar Chart of Top 5 and Bottom 5 States')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Relationships between Variables

# %% [markdown]
# Is there a relationship between the frequency of extreme weather events, and the percentage of positive responses to statements within questions?

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 5))

sns.scatterplot(
    event_count_merged, 
    x = "COUNT", 
    y = "percentage", 
    hue = "varname"
).set(
    title='Percent Responses in Favor of Climate Opinion Question \n in Relation to the Frequency of Weather Events',
    xlabel = "Frequency",
    ylabel = "Percentage"
)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1));

# %% [markdown]
# It is seen clearly that the climate opinion question shapes the relationship between percent responses and frequency of extreme weather events. For all questions, most points cluster around the y-axis with frequencies below 400.
# <br><br><br><br>
# Is there a relationship between occurences of extreme weather events and the number of respondents that believe in climate change?
# We will measure the  number of respondents that believe in climate change as the percentage that agree with the statement amongst all responses to the following questions:
# -  is global warming is affecting the weather?
# - Are you worried about global warming?
# - Do you discuss global warming at least occasionally?

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

sns.scatterplot(
    event_count_merged.query("varname in ['affectweather', 'worried', 'discuss']"), 
    x = "COUNT", 
    y = "percentage",
    hue = 'varname'
).set(
    title = 'Percent Responses in Favor of Climate Opinion Question \n in Relation to the Frequency of Weather Events',
    xlabel = "Frequency",
    ylabel = "Percentage"
)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1));

# %% [markdown]
# Both scatterplots show a mirrored pattern over the x-axis, frequency, that reflect the different categories of questions. It seems as though the relation between percentage and frequency of weather events are similar for `worried` and `affectweather`.

# %% [markdown]
# ### Outliers

# %%
count_sum = event_count_df.groupby('STATE').sum(numeric_only=True)
sns.boxplot(data=count_sum, x='COUNT')
plt.title('Distribution of total extreme events by state (2018-2023)')
plt.show()

# %% [markdown]
# It looks like most states are between 0 and 2500 events in this period, with the exception of one. Lets look at this outlier:

# %%
outlier = count_sum[count_sum['COUNT'] > 2500]
outlier
# Out:
#        COUNT   YEAR
# STATE
# TEXAS   4001  12123

# %% [markdown]
# As we can see from the code above, this outlier is Texas. As Texas is the second largest state in the US by land area, this checks out.

# %%
event_type_sum = events_df.groupby('EVENT_TYPE').count()
sns.boxplot(data=event_type_sum, x='EPISODE_ID')
plt.title('Distribution of number of extreme weather events by type (2018-2023)')
plt.xlabel('Event count')
plt.ylabel('Number of different event types')
plt.show()

# %% [markdown]
# This histogram suggests that there are eight events that are much more frequent than all others. Lets see what they are:

# %%
outliers = event_type_sum[event_type_sum['EPISODE_ID'] > 2500]
outliers
# Out:
#                    STATE   YEAR  EPISODE_ID  EPISODE_NARRATIVE  \
# EVENT_TYPE
# Drought             2590   2590        2590               2590
# Flash Flood         4074   4074        4074               4074
# Flood               3356   3356        3356               3356
# Hail                7836   7836        7836               7836
# High Wind           4354   4354        4354               4354
# Thunderstorm Wind  12867  12867       12867              12867
# Winter Weather      3203   3203        3203               3203
#
#                    INJURIES_DIRECT  INJURIES_INDIRECT  DEATHS_DIRECT  \
# EVENT_TYPE
# Drought                       2590               2590           2590
# Flash Flood                   4074               4074           4074
# Flood                         3356               3356           3356
# Hail                          7836               7836           7836
# High Wind                     4354               4354           4354
# Thunderstorm Wind            12867              12867          12867
# Winter Weather                3203               3203           3203
#
#                    DEATHS_INDIRECT
# EVENT_TYPE
# Drought                       2590
# Flash Flood                   4074
# Flood                         3356
# Hail                          7836
# High Wind                     4354
# Thunderstorm Wind            12867
# Winter Weather                3203

# %% [markdown]
# These eight events are all known to happen quite frequently, meaning that there is reason for these to all be outliers.

# %% [markdown]
# As for the Yale Climate dataset, lets look at some of the most pertinent questions and their distributions across states:

# %% [markdown]
# 1. Average estimated percentage who somewhat/strongly agree that global warming is affecting the weather in the United States

# %%
affect_weather = yale_climate[yale_climate['varname'] == 'affectweather'].groupby('geoname').mean(numeric_only=True)
sns.boxplot(data=affect_weather, x='percentage')
# Out:
# <Axes: xlabel='percentage'>

# %% [markdown]
# This distribution is roughly normal with no significant outliers. Lets see if other questions follow a similar distribution.

# %% [markdown]
# 2. Average estimated percentage who are somewhat/very worried about global warming

# %%
worried = yale_climate[yale_climate['varname'] == 'worried'].groupby('geoname').mean(numeric_only=True)
sns.boxplot(data=worried, x='percentage')
# Out:
# <Axes: xlabel='percentage'>

# %% [markdown]
# Although this distribution is slightly different, it still follows a roughly normal distribution, with the percentages still lying within 45-75%.

# %% [markdown]
# 3. Average estimated percentage who somewhat/strongly support funding research into renewable energy sources

# %%
research = yale_climate[yale_climate['varname'] == 'fundrenewables'].groupby('geoname').mean(numeric_only=True)
sns.boxplot(data=research, x='percentage')
# Out:
# <Axes: xlabel='percentage'>

# %% [markdown]
# This distribution also contains no significant outliers, but it does tend to be more skewed right than the other distributions. It also has a much higher range than the other questions.

# %% [markdown]
# # Analysis

# %% [markdown]
# > What (if any) analyses have already been performed on this data (or another similar dataset)?<br>
# > You should provide references to this<br>
# > What types of analyses did you perform?

# %% [markdown]
# ## Linear Regression Model for Predicting Climate Opinion
#
# One way of understanding the relationship between extreme weather events and climate opinion is building linear regression models. These can show how well a selection of variables can predict a response variable (in this case, climate opinion).
#
# Lets start by looking at a simple model predicting climate opinion from state event counts over the past six years:

# %%
research_questions = ['affectweather', 'worried', 'regulate', 'governor', 'discuss'] 
count_models = []
for question in research_questions:
    filtered = event_count_merged[event_count_merged['varname'] == question].groupby('STATE').agg({'COUNT': 'sum', 'percentage': 'mean'})
    model = smf.ols('percentage ~ 1 + COUNT', filtered).fit()
    count_models.append(model)
    print(question + ':')
    print(model.summary().tables[1])
    print('\n')
# Out:
# affectweather:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     61.3325      1.764     34.778      0.000      57.787      64.878
# COUNT         -0.0012      0.001     -0.847      0.401      -0.004       0.002
# ==============================================================================
#
#
# worried:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     61.8089      1.607     38.472      0.000      58.579      65.039
# COUNT         -0.0004      0.001     -0.334      0.740      -0.003       0.002
# ==============================================================================
#
#
# regulate:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     74.0474      0.944     78.461      0.000      72.150      75.945
# COUNT         -0.0010      0.001     -1.386      0.172      -0.003       0.000
# ==============================================================================
#
#
# governor:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     53.8917      1.145     47.053      0.000      51.589      56.195
# COUNT         -0.0004      0.001     -0.457      0.650      -0.002       0.001
# ==============================================================================
#
#
# discuss:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.3317      1.317     27.579      0.000      33.683      38.980
# COUNT         -0.0009      0.001     -0.862      0.393      -0.003       0.001
# ==============================================================================

# %% [markdown]
# The results from these models show that in general, there is no significant correlation between number of events in a state and climate opinion. The lowest pvalue was for 'regulate' with 0.172, which is not statistically significant. Also, all models had a slight negative coefficient, suggesting that if anything there might be a small negative correlation between number of extreme weather events and people believing in climate change/wanting the government to do more for it.

# %% [markdown]
# Another model we can look at is one that uses the event_df_

# %%
categorized = events_df_merged.copy()
categorized['EVENT_TYPE'] = pd.Categorical(categorized['EVENT_TYPE'])

# %%
event_models = []
for question in research_questions:
    filtered = categorized[categorized['varname'] == question]
    model = smf.ols('percentage ~ EVENT_TYPE + INJURIES_DIRECT + INJURIES_INDIRECT + DEATHS_DIRECT + DEATHS_INDIRECT', filtered).fit()
    event_models.append(model)
    print(question + ':')
    print(model.summary().tables[1])
    print('\n')
# Out:
# affectweather:
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                58.5667      0.828     70.749      0.000      56.944      60.189
# EVENT_TYPE[T.Avalanche]                   0.6943      1.008      0.689      0.491      -1.282       2.670
# EVENT_TYPE[T.Blizzard]                   -1.0318      0.878     -1.174      0.240      -2.754       0.690
# EVENT_TYPE[T.Coastal Flood]               5.7288      0.888      6.449      0.000       3.988       7.470
# EVENT_TYPE[T.Cold/Wind Chill]             1.6917      0.887      1.908      0.056      -0.046       3.430
# EVENT_TYPE[T.Debris Flow]                 4.7570      0.950      5.010      0.000       2.896       6.618
# EVENT_TYPE[T.Dense Fog]                   4.4127      0.856      5.157      0.000       2.736       6.090
# EVENT_TYPE[T.Dense Smoke]                 3.0791      1.623      1.898      0.058      -0.101       6.259
# EVENT_TYPE[T.Drought]                     0.4860      0.836      0.581      0.561      -1.153       2.125
# EVENT_TYPE[T.Dust Devil]                  1.9600      1.386      1.414      0.157      -0.756       4.676
# EVENT_TYPE[T.Dust Storm]                  3.4506      0.964      3.580      0.000       1.561       5.340
# EVENT_TYPE[T.Excessive Heat]              1.9322      0.855      2.260      0.024       0.256       3.608
# EVENT_TYPE[T.Extreme Cold/Wind Chill]     0.3434      0.879      0.391      0.696      -1.379       2.065
# EVENT_TYPE[T.Flash Flood]                 1.4005      0.833      1.681      0.093      -0.233       3.034
# EVENT_TYPE[T.Flood]                       0.2415      0.834      0.289      0.772      -1.394       1.877
# EVENT_TYPE[T.Freezing Fog]               -1.3334      1.401     -0.952      0.341      -4.080       1.413
# EVENT_TYPE[T.Frost/Freeze]                3.4375      0.862      3.987      0.000       1.748       5.127
# EVENT_TYPE[T.Funnel Cloud]                0.7470      0.869      0.860      0.390      -0.955       2.449
# EVENT_TYPE[T.Hail]                       -0.8384      0.831     -1.009      0.313      -2.466       0.790
# EVENT_TYPE[T.Heat]                        0.1890      0.849      0.223      0.824      -1.474       1.852
# EVENT_TYPE[T.Heavy Rain]                  3.9653      0.855      4.637      0.000       2.289       5.641
# EVENT_TYPE[T.Heavy Snow]                  2.0160      0.838      2.406      0.016       0.374       3.658
# EVENT_TYPE[T.High Surf]                   8.6829      0.905      9.589      0.000       6.908      10.458
# EVENT_TYPE[T.High Wind]                   1.1583      0.833      1.391      0.164      -0.474       2.791
# EVENT_TYPE[T.Hurricane]                   0.8900      1.836      0.485      0.628      -2.709       4.489
# EVENT_TYPE[T.Ice Storm]                  -0.1902      0.950     -0.200      0.841      -2.053       1.672
# EVENT_TYPE[T.Lake-Effect Snow]            7.5475      0.976      7.730      0.000       5.634       9.461
# EVENT_TYPE[T.Lakeshore Flood]             3.2641      1.054      3.097      0.002       1.199       5.330
# EVENT_TYPE[T.Lightning]                   2.3707      0.864      2.744      0.006       0.677       4.064
# EVENT_TYPE[T.Rip Current]                 3.1135      0.882      3.530      0.000       1.385       4.842
# EVENT_TYPE[T.Seiche]                      1.6067      2.618      0.614      0.539      -3.524       6.737
# EVENT_TYPE[T.Sleet]                      -0.9612      1.824     -0.527      0.598      -4.537       2.615
# EVENT_TYPE[T.Sneakerwave]                 7.1251      2.012      3.541      0.000       3.181      11.069
# EVENT_TYPE[T.Storm Surge/Tide]            1.3770      1.385      0.994      0.320      -1.338       4.092
# EVENT_TYPE[T.Strong Wind]                 3.0499      0.851      3.584      0.000       1.382       4.718
# EVENT_TYPE[T.Thunderstorm Wind]           0.4200      0.830      0.506      0.613      -1.206       2.046
# EVENT_TYPE[T.Tornado]                     0.1309      0.844      0.155      0.877      -1.523       1.784
# EVENT_TYPE[T.Tropical Depression]         0.4335      1.539      0.282      0.778      -2.582       3.449
# EVENT_TYPE[T.Tropical Storm]              2.4753      0.972      2.548      0.011       0.571       4.380
# EVENT_TYPE[T.Tsunami]                     8.4873      2.844      2.985      0.003       2.914      14.061
# EVENT_TYPE[T.Volcanic Ashfall]            8.4800      1.941      4.368      0.000       4.675      12.285
# EVENT_TYPE[T.Wildfire]                    3.0458      0.842      3.618      0.000       1.396       4.696
# EVENT_TYPE[T.Winter Storm]                0.7799      0.838      0.930      0.352      -0.863       2.423
# EVENT_TYPE[T.Winter Weather]              1.5541      0.835      1.862      0.063      -0.082       3.190
# INJURIES_DIRECT                          -0.0139      0.026     -0.534      0.593      -0.065       0.037
# INJURIES_INDIRECT                        -0.0686      0.059     -1.158      0.247      -0.185       0.047
# DEATHS_DIRECT                             0.0825      0.038      2.147      0.032       0.007       0.158
# DEATHS_INDIRECT                           0.1777      0.200      0.889      0.374      -0.214       0.570
# =========================================================================================================
#
#
# worried:
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                61.7972      0.764     80.939      0.000      60.301      63.294
# EVENT_TYPE[T.Avalanche]                  -1.3181      0.930     -1.417      0.156      -3.141       0.505
# EVENT_TYPE[T.Blizzard]                   -3.2452      0.810     -4.005      0.000      -4.833      -1.657
# EVENT_TYPE[T.Coastal Flood]               3.8224      0.819      4.665      0.000       2.216       5.428
# EVENT_TYPE[T.Cold/Wind Chill]            -0.2002      0.818     -0.245      0.807      -1.803       1.403
# EVENT_TYPE[T.Debris Flow]                 2.6710      0.876      3.050      0.002       0.954       4.388
# EVENT_TYPE[T.Dense Fog]                   2.8043      0.789      3.553      0.000       1.258       4.351
# EVENT_TYPE[T.Dense Smoke]                 1.8501      1.497      1.236      0.216      -1.083       4.783
# EVENT_TYPE[T.Drought]                    -0.4844      0.771     -0.628      0.530      -1.996       1.028
# EVENT_TYPE[T.Dust Devil]                  1.1019      1.278      0.862      0.389      -1.403       3.607
# EVENT_TYPE[T.Dust Storm]                  1.9149      0.889      2.154      0.031       0.172       3.657
# EVENT_TYPE[T.Excessive Heat]              0.8866      0.789      1.124      0.261      -0.659       2.432
# EVENT_TYPE[T.Extreme Cold/Wind Chill]    -2.2786      0.810     -2.812      0.005      -3.867      -0.690
# EVENT_TYPE[T.Flash Flood]                 0.0149      0.769      0.019      0.985      -1.491       1.521
# EVENT_TYPE[T.Flood]                      -1.6157      0.770     -2.099      0.036      -3.124      -0.107
# EVENT_TYPE[T.Freezing Fog]               -2.9639      1.292     -2.293      0.022      -5.497      -0.431
# EVENT_TYPE[T.Frost/Freeze]                1.7069      0.795      2.147      0.032       0.148       3.265
# EVENT_TYPE[T.Funnel Cloud]               -0.9312      0.801     -1.162      0.245      -2.501       0.639
# EVENT_TYPE[T.Hail]                       -2.4764      0.766     -3.232      0.001      -3.978      -0.975
# EVENT_TYPE[T.Heat]                       -0.5509      0.783     -0.704      0.482      -2.085       0.983
# EVENT_TYPE[T.Heavy Rain]                  2.5367      0.789      3.216      0.001       0.991       4.083
# EVENT_TYPE[T.Heavy Snow]                 -0.0815      0.773     -0.105      0.916      -1.596       1.433
# EVENT_TYPE[T.High Surf]                   7.9001      0.835      9.460      0.000       6.263       9.537
# EVENT_TYPE[T.High Wind]                  -0.2784      0.768     -0.362      0.717      -1.784       1.227
# EVENT_TYPE[T.Hurricane]                   0.6598      1.694      0.390      0.697      -2.660       3.979
# EVENT_TYPE[T.Ice Storm]                  -2.0028      0.876     -2.285      0.022      -3.721      -0.285
# EVENT_TYPE[T.Lake-Effect Snow]            4.9382      0.901      5.483      0.000       3.173       6.703
# EVENT_TYPE[T.Lakeshore Flood]            -0.9059      0.972     -0.932      0.351      -2.811       0.999
# EVENT_TYPE[T.Lightning]                   0.9663      0.797      1.213      0.225      -0.596       2.528
# EVENT_TYPE[T.Rip Current]                 1.8944      0.813      2.329      0.020       0.300       3.489
# EVENT_TYPE[T.Seiche]                     -2.6606      2.414     -1.102      0.270      -7.393       2.072
# EVENT_TYPE[T.Sleet]                      -2.0498      1.683     -1.218      0.223      -5.348       1.248
# EVENT_TYPE[T.Sneakerwave]                 5.7428      1.856      3.094      0.002       2.105       9.381
# EVENT_TYPE[T.Storm Surge/Tide]            0.8489      1.278      0.664      0.506      -1.655       3.353
# EVENT_TYPE[T.Strong Wind]                 1.0917      0.785      1.391      0.164      -0.446       2.630
# EVENT_TYPE[T.Thunderstorm Wind]          -1.1829      0.765     -1.546      0.122      -2.682       0.317
# EVENT_TYPE[T.Tornado]                    -1.3060      0.778     -1.679      0.093      -2.831       0.219
# EVENT_TYPE[T.Tropical Depression]        -0.6099      1.419     -0.430      0.667      -3.391       2.172
# EVENT_TYPE[T.Tropical Storm]              1.0598      0.896      1.183      0.237      -0.697       2.816
# EVENT_TYPE[T.Tsunami]                     7.0368      2.623      2.683      0.007       1.896      12.177
# EVENT_TYPE[T.Volcanic Ashfall]            8.2694      1.791      4.618      0.000       4.760      11.779
# EVENT_TYPE[T.Wildfire]                    2.0702      0.776      2.667      0.008       0.549       3.592
# EVENT_TYPE[T.Winter Storm]               -1.4109      0.773     -1.825      0.068      -2.926       0.104
# EVENT_TYPE[T.Winter Weather]             -0.5693      0.770     -0.739      0.460      -2.078       0.940
# INJURIES_DIRECT                           0.0089      0.024      0.372      0.710      -0.038       0.056
# INJURIES_INDIRECT                        -0.0645      0.055     -1.181      0.238      -0.172       0.043
# DEATHS_DIRECT                             0.0735      0.035      2.074      0.038       0.004       0.143
# DEATHS_INDIRECT                           0.1356      0.184      0.735      0.462      -0.226       0.497
# =========================================================================================================
#
#
# regulate:
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                71.9070      0.494    145.523      0.000      70.939      72.876
# EVENT_TYPE[T.Avalanche]                  -0.9632      0.602     -1.600      0.109      -2.143       0.216
# EVENT_TYPE[T.Blizzard]                   -0.9016      0.524     -1.719      0.086      -1.929       0.126
# EVENT_TYPE[T.Coastal Flood]               3.5859      0.530      6.762      0.000       2.547       4.625
# EVENT_TYPE[T.Cold/Wind Chill]             1.3100      0.529      2.475      0.013       0.272       2.347
# EVENT_TYPE[T.Debris Flow]                 1.3391      0.567      2.363      0.018       0.228       2.450
# EVENT_TYPE[T.Dense Fog]                   2.1545      0.511      4.218      0.000       1.153       3.156
# EVENT_TYPE[T.Dense Smoke]                 2.0456      0.969      2.112      0.035       0.147       3.944
# EVENT_TYPE[T.Drought]                    -0.7922      0.499     -1.587      0.113      -1.771       0.186
# EVENT_TYPE[T.Dust Devil]                  1.4080      0.827      1.702      0.089      -0.213       3.029
# EVENT_TYPE[T.Dust Storm]                  1.3733      0.575      2.387      0.017       0.246       2.501
# EVENT_TYPE[T.Excessive Heat]              0.4732      0.510      0.927      0.354      -0.527       1.474
# EVENT_TYPE[T.Extreme Cold/Wind Chill]     0.0994      0.524      0.189      0.850      -0.929       1.127
# EVENT_TYPE[T.Flash Flood]                 1.0969      0.497      2.205      0.027       0.122       2.072
# EVENT_TYPE[T.Flood]                       1.2802      0.498      2.570      0.010       0.304       2.256
# EVENT_TYPE[T.Freezing Fog]               -0.8397      0.836     -1.004      0.315      -2.479       0.800
# EVENT_TYPE[T.Frost/Freeze]                1.6746      0.515      3.254      0.001       0.666       2.683
# EVENT_TYPE[T.Funnel Cloud]                0.9842      0.518      1.898      0.058      -0.032       2.000
# EVENT_TYPE[T.Hail]                       -0.2345      0.496     -0.473      0.636      -1.206       0.737
# EVENT_TYPE[T.Heat]                        0.0871      0.507      0.172      0.863      -0.906       1.080
# EVENT_TYPE[T.Heavy Rain]                  2.0589      0.510      4.034      0.000       1.058       3.059
# EVENT_TYPE[T.Heavy Snow]                  0.8591      0.500      1.718      0.086      -0.121       1.839
# EVENT_TYPE[T.High Surf]                   3.8867      0.540      7.191      0.000       2.827       4.946
# EVENT_TYPE[T.High Wind]                  -0.2129      0.497     -0.428      0.669      -1.187       0.762
# EVENT_TYPE[T.Hurricane]                   1.3885      1.096      1.267      0.205      -0.760       3.537
# EVENT_TYPE[T.Ice Storm]                   0.2639      0.567      0.465      0.642      -0.848       1.376
# EVENT_TYPE[T.Lake-Effect Snow]            5.6594      0.583      9.710      0.000       4.517       6.802
# EVENT_TYPE[T.Lakeshore Flood]             3.5493      0.629      5.642      0.000       2.316       4.782
# EVENT_TYPE[T.Lightning]                   2.1850      0.516      4.236      0.000       1.174       3.196
# EVENT_TYPE[T.Rip Current]                 2.2906      0.526      4.351      0.000       1.259       3.323
# EVENT_TYPE[T.Seiche]                      3.1796      1.563      2.035      0.042       0.117       6.242
# EVENT_TYPE[T.Sleet]                       0.2007      1.089      0.184      0.854      -1.934       2.335
# EVENT_TYPE[T.Sneakerwave]                 2.7360      1.201      2.278      0.023       0.382       5.090
# EVENT_TYPE[T.Storm Surge/Tide]            0.3374      0.827      0.408      0.683      -1.283       1.958
# EVENT_TYPE[T.Strong Wind]                 2.0942      0.508      4.123      0.000       1.099       3.090
# EVENT_TYPE[T.Thunderstorm Wind]           0.7118      0.495      1.438      0.151      -0.259       1.682
# EVENT_TYPE[T.Tornado]                     0.5678      0.504      1.128      0.259      -0.419       1.555
# EVENT_TYPE[T.Tropical Depression]         0.3942      0.918      0.429      0.668      -1.406       2.194
# EVENT_TYPE[T.Tropical Storm]              1.4848      0.580      2.560      0.010       0.348       2.622
# EVENT_TYPE[T.Tsunami]                     3.5150      1.697      2.071      0.038       0.188       6.842
# EVENT_TYPE[T.Volcanic Ashfall]            5.2738      1.159      4.551      0.000       3.002       7.545
# EVENT_TYPE[T.Wildfire]                    1.1392      0.502      2.267      0.023       0.154       2.124
# EVENT_TYPE[T.Winter Storm]                0.7509      0.500      1.501      0.133      -0.230       1.732
# EVENT_TYPE[T.Winter Weather]              1.1855      0.498      2.379      0.017       0.209       2.162
# INJURIES_DIRECT                           0.0230      0.016      1.478      0.140      -0.007       0.053
# INJURIES_INDIRECT                        -0.0563      0.035     -1.592      0.111      -0.126       0.013
# DEATHS_DIRECT                             0.0423      0.023      1.844      0.065      -0.003       0.087
# DEATHS_INDIRECT                           0.2686      0.119      2.250      0.024       0.035       0.502
# =========================================================================================================
#
#
# governor:
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                53.8631      0.598     90.095      0.000      52.691      55.035
# EVENT_TYPE[T.Avalanche]                  -3.8333      0.728     -5.264      0.000      -5.260      -2.406
# EVENT_TYPE[T.Blizzard]                   -4.4032      0.634     -6.940      0.000      -5.647      -3.160
# EVENT_TYPE[T.Coastal Flood]               3.7667      0.642      5.871      0.000       2.509       5.024
# EVENT_TYPE[T.Cold/Wind Chill]            -0.4755      0.640     -0.742      0.458      -1.731       0.780
# EVENT_TYPE[T.Debris Flow]                -1.3192      0.686     -1.924      0.054      -2.663       0.025
# EVENT_TYPE[T.Dense Fog]                  -0.0302      0.618     -0.049      0.961      -1.241       1.181
# EVENT_TYPE[T.Dense Smoke]                -2.0595      1.172     -1.757      0.079      -4.356       0.237
# EVENT_TYPE[T.Drought]                    -1.3640      0.604     -2.258      0.024      -2.548      -0.180
# EVENT_TYPE[T.Dust Devil]                 -0.1335      1.001     -0.133      0.894      -2.095       1.828
# EVENT_TYPE[T.Dust Storm]                 -1.2079      0.696     -1.735      0.083      -2.572       0.156
# EVENT_TYPE[T.Excessive Heat]             -0.7025      0.618     -1.138      0.255      -1.913       0.508
# EVENT_TYPE[T.Extreme Cold/Wind Chill]    -2.6754      0.635     -4.216      0.000      -3.919      -1.432
# EVENT_TYPE[T.Flash Flood]                 0.5267      0.602      0.875      0.381      -0.653       1.706
# EVENT_TYPE[T.Flood]                      -0.1314      0.603     -0.218      0.827      -1.313       1.050
# EVENT_TYPE[T.Freezing Fog]               -3.3579      1.012     -3.318      0.001      -5.341      -1.374
# EVENT_TYPE[T.Frost/Freeze]               -0.5718      0.623     -0.918      0.358      -1.792       0.648
# EVENT_TYPE[T.Funnel Cloud]               -0.3480      0.627     -0.555      0.579      -1.577       0.881
# EVENT_TYPE[T.Hail]                       -1.5166      0.600     -2.528      0.011      -2.692      -0.341
# EVENT_TYPE[T.Heat]                       -0.2883      0.613     -0.470      0.638      -1.490       0.913
# EVENT_TYPE[T.Heavy Rain]                  1.2429      0.618      2.013      0.044       0.032       2.453
# EVENT_TYPE[T.Heavy Snow]                 -1.8579      0.605     -3.071      0.002      -3.044      -0.672
# EVENT_TYPE[T.High Surf]                   2.1923      0.654      3.352      0.001       0.911       3.474
# EVENT_TYPE[T.High Wind]                  -2.2796      0.602     -3.790      0.000      -3.459      -1.101
# EVENT_TYPE[T.Hurricane]                   1.6802      1.326      1.267      0.205      -0.919       4.280
# EVENT_TYPE[T.Ice Storm]                  -0.9578      0.686     -1.396      0.163      -2.303       0.387
# EVENT_TYPE[T.Lake-Effect Snow]            4.4358      0.705      6.290      0.000       3.054       5.818
# EVENT_TYPE[T.Lakeshore Flood]             1.7370      0.761      2.282      0.022       0.245       3.229
# EVENT_TYPE[T.Lightning]                   2.2027      0.624      3.530      0.000       0.980       3.426
# EVENT_TYPE[T.Rip Current]                 3.1328      0.637      4.918      0.000       1.884       4.381
# EVENT_TYPE[T.Seiche]                      1.0785      1.891      0.570      0.568      -2.627       4.784
# EVENT_TYPE[T.Sleet]                      -0.9042      1.318     -0.686      0.493      -3.487       1.678
# EVENT_TYPE[T.Sneakerwave]                -0.4946      1.453     -0.340      0.734      -3.343       2.354
# EVENT_TYPE[T.Storm Surge/Tide]           -0.0666      1.000     -0.067      0.947      -2.027       1.894
# EVENT_TYPE[T.Strong Wind]                 0.7106      0.615      1.156      0.248      -0.494       1.915
# EVENT_TYPE[T.Thunderstorm Wind]           0.1770      0.599      0.295      0.768      -0.997       1.351
# EVENT_TYPE[T.Tornado]                     0.1796      0.609      0.295      0.768      -1.015       1.374
# EVENT_TYPE[T.Tropical Depression]         2.0509      1.111      1.846      0.065      -0.127       4.229
# EVENT_TYPE[T.Tropical Storm]              2.5298      0.702      3.605      0.000       1.154       3.905
# EVENT_TYPE[T.Tsunami]                    -1.4391      2.054     -0.701      0.483      -5.464       2.586
# EVENT_TYPE[T.Volcanic Ashfall]            2.7977      1.402      1.995      0.046       0.050       5.546
# EVENT_TYPE[T.Wildfire]                   -0.7583      0.608     -1.247      0.212      -1.950       0.433
# EVENT_TYPE[T.Winter Storm]               -1.4271      0.605     -2.357      0.018      -2.614      -0.241
# EVENT_TYPE[T.Winter Weather]             -0.5744      0.603     -0.953      0.341      -1.756       0.607
# INJURIES_DIRECT                           0.0014      0.019      0.074      0.941      -0.035       0.038
# INJURIES_INDIRECT                        -0.0083      0.043     -0.193      0.847      -0.092       0.076
# DEATHS_DIRECT                             0.0307      0.028      1.107      0.268      -0.024       0.085
# DEATHS_INDIRECT                          -0.0479      0.144     -0.331      0.740      -0.331       0.235
# =========================================================================================================
#
#
# discuss:
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                32.6446      0.600     54.440      0.000      31.469      33.820
# EVENT_TYPE[T.Avalanche]                   5.3969      0.730      7.389      0.000       3.965       6.828
# EVENT_TYPE[T.Blizzard]                    3.1700      0.636      4.982      0.000       1.923       4.417
# EVENT_TYPE[T.Coastal Flood]               4.8202      0.644      7.490      0.000       3.559       6.081
# EVENT_TYPE[T.Cold/Wind Chill]             2.8269      0.642      4.401      0.000       1.568       4.086
# EVENT_TYPE[T.Debris Flow]                 6.8389      0.688      9.943      0.000       5.491       8.187
# EVENT_TYPE[T.Dense Fog]                   6.0612      0.620      9.779      0.000       4.846       7.276
# EVENT_TYPE[T.Dense Smoke]                 7.3038      1.175      6.214      0.000       5.000       9.608
# EVENT_TYPE[T.Drought]                     1.2465      0.606      2.057      0.040       0.059       2.434
# EVENT_TYPE[T.Dust Devil]                  4.9992      1.004      4.980      0.000       3.032       6.967
# EVENT_TYPE[T.Dust Storm]                  5.5425      0.698      7.938      0.000       4.174       6.911
# EVENT_TYPE[T.Excessive Heat]              3.1658      0.619      5.111      0.000       1.952       4.380
# EVENT_TYPE[T.Extreme Cold/Wind Chill]     2.3537      0.636      3.698      0.000       1.106       3.601
# EVENT_TYPE[T.Flash Flood]                 2.0978      0.604      3.475      0.001       0.915       3.281
# EVENT_TYPE[T.Flood]                       2.1767      0.604      3.601      0.000       0.992       3.361
# EVENT_TYPE[T.Freezing Fog]                2.0134      1.015      1.984      0.047       0.024       4.003
# EVENT_TYPE[T.Frost/Freeze]                5.4556      0.624      8.736      0.000       4.232       6.680
# EVENT_TYPE[T.Funnel Cloud]                2.7925      0.629      4.439      0.000       1.559       4.026
# EVENT_TYPE[T.Hail]                        1.1695      0.602      1.944      0.052      -0.010       2.349
# EVENT_TYPE[T.Heat]                        1.3191      0.615      2.146      0.032       0.114       2.524
# EVENT_TYPE[T.Heavy Rain]                  5.2744      0.619      8.515      0.000       4.060       6.489
# EVENT_TYPE[T.Heavy Snow]                  4.8586      0.607      8.006      0.000       3.669       6.048
# EVENT_TYPE[T.High Surf]                  11.0008      0.656     16.772      0.000       9.715      12.286
# EVENT_TYPE[T.High Wind]                   4.0021      0.603      6.633      0.000       2.820       5.185
# EVENT_TYPE[T.Hurricane]                   0.1541      1.330      0.116      0.908      -2.453       2.761
# EVENT_TYPE[T.Ice Storm]                   1.0516      0.688      1.528      0.127      -0.298       2.401
# EVENT_TYPE[T.Lake-Effect Snow]            4.5870      0.707      6.485      0.000       3.201       5.973
# EVENT_TYPE[T.Lakeshore Flood]             2.2063      0.763      2.890      0.004       0.710       3.703
# EVENT_TYPE[T.Lightning]                   2.3863      0.626      3.813      0.000       1.160       3.613
# EVENT_TYPE[T.Rip Current]                 2.7355      0.639      4.282      0.000       1.483       3.988
# EVENT_TYPE[T.Seiche]                      1.3854      1.896      0.731      0.465      -2.331       5.102
# EVENT_TYPE[T.Sleet]                       0.3647      1.322      0.276      0.783      -2.226       2.955
# EVENT_TYPE[T.Sneakerwave]                11.0788      1.458      7.600      0.000       8.222      13.936
# EVENT_TYPE[T.Storm Surge/Tide]            0.2285      1.003      0.228      0.820      -1.738       2.195
# EVENT_TYPE[T.Strong Wind]                 3.4588      0.616      5.612      0.000       2.251       4.667
# EVENT_TYPE[T.Thunderstorm Wind]           1.1100      0.601      1.847      0.065      -0.068       2.288
# EVENT_TYPE[T.Tornado]                     0.9527      0.611      1.559      0.119      -0.245       2.150
# EVENT_TYPE[T.Tropical Depression]        -0.2620      1.115     -0.235      0.814      -2.446       1.922
# EVENT_TYPE[T.Tropical Storm]              1.1168      0.704      1.587      0.113      -0.263       2.496
# EVENT_TYPE[T.Tsunami]                     9.0914      2.060      4.414      0.000       5.054      13.129
# EVENT_TYPE[T.Volcanic Ashfall]           12.3170      1.406      8.758      0.000       9.561      15.073
# EVENT_TYPE[T.Wildfire]                    5.5238      0.610      9.059      0.000       4.329       6.719
# EVENT_TYPE[T.Winter Storm]                2.9581      0.607      4.872      0.000       1.768       4.148
# EVENT_TYPE[T.Winter Weather]              2.6867      0.605      4.443      0.000       1.502       3.872
# INJURIES_DIRECT                           0.0119      0.019      0.629      0.530      -0.025       0.049
# INJURIES_INDIRECT                        -0.1069      0.043     -2.492      0.013      -0.191      -0.023
# DEATHS_DIRECT                             0.0767      0.028      2.757      0.006       0.022       0.131
# DEATHS_INDIRECT                           0.5858      0.145      4.045      0.000       0.302       0.870
# =========================================================================================================

# %% [markdown]
# Looking through the tables below, we can indentify some patterns. For one, the DEATHS_DIRECT seems to have a statistically signficant positive correlation with percentage across all questions. INJURIES_DIRECT, INJURIES_INDIRECT, and DEATHS_INDIRECT do not seem to have any statistically significant correlation with percentage. For the different event types, it seems that there is a lot of variance across the different types and the different research questions. Some of the coefficients are negative, although most are positive.
#
# Many event types have stastically significant results for one question but not all. Some types, such as Lake-Effect Snow, Coastal Flood, and Rip Current have stastically significant positive correlations across all questions. This suggests that areas that have these events more frequently might be more likely to be more conscientious about climate change.
#
# Another pattern in these results is that some research questions have much more statistically significant results than others. For example, 'discuss' has p-values of under 0.05 for almost all variables. On the other hand, 'worried' has few p-values less than 0.05.

# %% [markdown]
# ## Assumptions for Linear Regression
#
# To make sure that Linear Regression is a valid method of analysis for these models, we must run some diagnostics to make sure the assumptions are met

# %% [markdown]
# ### Normality

# %%
#used to standardize residuals
def standardize(X):
    return (X - X.mean()) / X.std()

# %% [markdown]
# QQ plots for Event Count Models:

# %%
fig, axs = plt.subplots(2,3, figsize=(14,14))
for i, (model, ax) in enumerate(zip(count_models, axs.ravel())):
    sm.qqplot(standardize(model.resid), line='45', ax=ax)
    ax.set_title(f'Question {i + 1}')

# %% [markdown]
# We can see that all plots here roughly follow the line, so we can assume this assumption is met.

# %% [markdown]
# QQ Plots for Event Type models:

# %%
fig, axs = plt.subplots(2,3, figsize=(14,14))
for i, (model, ax) in enumerate(zip(event_models, axs.ravel())):
    sm.qqplot(standardize(model.resid), line='45', ax=ax)
    ax.set_title(f'Question {i + 1}')

# %% [markdown]
# ### Heteroscedasticity and Linearity

# %% [markdown]
# Fitted vs Standardized Residuals for Event Count Models:

# %%
fig, axs = plt.subplots(2,3, figsize=(14,14))

for i, (model, ax) in enumerate(zip(count_models, axs.ravel())):
    ax.scatter(model.fittedvalues, standardize(model.resid))
    ax.set_xlabel('Fitted values')
    ax.set_ylabel('Standardized residuals')
    ax.set_title(f'Question {i+1}')

# %% [markdown]
# Fitted vs Standardized Residuals for Event Type Models:

# %%
fig, axs = plt.subplots(2,3, figsize=(14,14))

for i, (model, ax) in enumerate(zip(event_models, axs.ravel())):
    ax.scatter(model.fittedvalues, standardize(model.resid))
    ax.set_xlabel('Fitted values')
    ax.set_ylabel('Standardized residuals')
    ax.set_title(f'Question {i+1}')

# %% [markdown]
# ### Indpendence

# %% [markdown]
# Index vs. Standardized Residuals for Event Count Models:

# %%
fig, axs = plt.subplots(2,3, figsize=(14,14))

for i, (model, ax) in enumerate(zip(count_models, axs.ravel())):
    ax.scatter(range(len(model.resid)), standardize(model.resid))
    ax.set_xlabel('Index')
    ax.set_ylabel('Standardized residuals')
    ax.set_title(f'Question {i+1}')

# %% [markdown]
# Index vs Standardized residuals for Event Type Models:

# %%
fig, axs = plt.subplots(2,3, figsize=(14,14))

for i, (model, ax) in enumerate(zip(event_models, axs.ravel())):
    ax.scatter(range(len(model.resid)), standardize(model.resid))
    ax.set_xlabel('Index')
    ax.set_ylabel('Standardized residuals')
    ax.set_title(f'Question {i+1}')

# %% [markdown]
# ### Variance Inflation Factor (VIF)

# %%
q_num = 1
for model in event_models:
    print(f'Question {q_num}')
    q_num += 1
    exog = model.model.exog
    names = model.params.index
    for i in range(1, exog.shape[1]):
        print(f'VIF: {names[i]}: {variance_inflation_factor(exog, i)}')
# Out:
# Question 1
# VIF: EVENT_TYPE[T.Avalanche]: 3.070603413485773
# VIF: EVENT_TYPE[T.Blizzard]: 8.856918339102132
# VIF: EVENT_TYPE[T.Coastal Flood]: 7.543749070918439
# VIF: EVENT_TYPE[T.Cold/Wind Chill]: 7.747268398897487
# VIF: EVENT_TYPE[T.Debris Flow]: 4.153848387864669
# VIF: EVENT_TYPE[T.Dense Fog]: 15.522447979314652
# VIF: EVENT_TYPE[T.Dense Smoke]: 1.3513877092908162
# VIF: EVENT_TYPE[T.Drought]: 46.67137702765306
# VIF: EVENT_TYPE[T.Dust Devil]: 1.55606222644243
# VIF: EVENT_TYPE[T.Dust Storm]: 3.805794079783224
# VIF: EVENT_TYPE[T.Excessive Heat]: 15.731828371762097
# VIF: EVENT_TYPE[T.Extreme Cold/Wind Chill]: 8.838704573527124
# VIF: EVENT_TYPE[T.Flash Flood]: 70.8167107104026
# VIF: EVENT_TYPE[T.Flood]: 59.318598368572786
# VIF: EVENT_TYPE[T.Freezing Fog]: 1.5380000589995382
# VIF: EVENT_TYPE[T.Frost/Freeze]: 12.685150465508615
# VIF: EVENT_TYPE[T.Funnel Cloud]: 10.820100083458625
# VIF: EVENT_TYPE[T.Hail]: 125.42178592243219
# VIF: EVENT_TYPE[T.Heat]: 20.628872087239458
# VIF: EVENT_TYPE[T.Heavy Rain]: 15.694569216455905
# VIF: EVENT_TYPE[T.Heavy Snow]: 40.50684749873572
# VIF: EVENT_TYPE[T.High Surf]: 6.062614060940351
# VIF: EVENT_TYPE[T.High Wind]: 75.20712016266317
# VIF: EVENT_TYPE[T.Hurricane]: 1.2754222655104408
# VIF: EVENT_TYPE[T.Ice Storm]: 4.135513906291466
# VIF: EVENT_TYPE[T.Lake-Effect Snow]: 3.5467083082564086
# VIF: EVENT_TYPE[T.Lakeshore Flood]: 2.607010463679314
# VIF: EVENT_TYPE[T.Lightning]: 12.053594168725542
# VIF: EVENT_TYPE[T.Rip Current]: 8.410311370682228
# VIF: EVENT_TYPE[T.Seiche]: 1.1109906415206467
# VIF: EVENT_TYPE[T.Sleet]: 1.259001640887042
# VIF: EVENT_TYPE[T.Sneakerwave]: 1.2035928796982507
# VIF: EVENT_TYPE[T.Storm Surge/Tide]: 1.5547177387663742
# VIF: EVENT_TYPE[T.Strong Wind]: 18.38083615771226
# VIF: EVENT_TYPE[T.Thunderstorm Wind]: 183.64276650073217
# VIF: EVENT_TYPE[T.Tornado]: 26.28046159694271
# VIF: EVENT_TYPE[T.Tropical Depression]: 1.4068487254236772
# VIF: EVENT_TYPE[T.Tropical Storm]: 3.638721762115962
# VIF: EVENT_TYPE[T.Tsunami]: 1.0924938744559625
# VIF: EVENT_TYPE[T.Volcanic Ashfall]: 1.2219571891232037
# VIF: EVENT_TYPE[T.Wildfire]: 29.676890736676903
# VIF: EVENT_TYPE[T.Winter Storm]: 38.973114464592584
# VIF: EVENT_TYPE[T.Winter Weather]: 56.8281238705693
# VIF: INJURIES_DIRECT: 1.0219920497734494
# VIF: INJURIES_INDIRECT: 1.075752820936885
# VIF: DEATHS_DIRECT: 1.0472250129058247
# VIF: DEATHS_INDIRECT: 1.1007911469020653
# Question 2
# VIF: EVENT_TYPE[T.Avalanche]: 3.070603413485773
# VIF: EVENT_TYPE[T.Blizzard]: 8.856918339102132
# VIF: EVENT_TYPE[T.Coastal Flood]: 7.543749070918439
# VIF: EVENT_TYPE[T.Cold/Wind Chill]: 7.747268398897487
# VIF: EVENT_TYPE[T.Debris Flow]: 4.153848387864669
# VIF: EVENT_TYPE[T.Dense Fog]: 15.522447979314652
# VIF: EVENT_TYPE[T.Dense Smoke]: 1.3513877092908162
# VIF: EVENT_TYPE[T.Drought]: 46.67137702765306
# VIF: EVENT_TYPE[T.Dust Devil]: 1.55606222644243
# VIF: EVENT_TYPE[T.Dust Storm]: 3.805794079783224
# VIF: EVENT_TYPE[T.Excessive Heat]: 15.731828371762097
# VIF: EVENT_TYPE[T.Extreme Cold/Wind Chill]: 8.838704573527124
# VIF: EVENT_TYPE[T.Flash Flood]: 70.8167107104026
# VIF: EVENT_TYPE[T.Flood]: 59.318598368572786
# VIF: EVENT_TYPE[T.Freezing Fog]: 1.5380000589995382
# VIF: EVENT_TYPE[T.Frost/Freeze]: 12.685150465508615
# VIF: EVENT_TYPE[T.Funnel Cloud]: 10.820100083458625
# VIF: EVENT_TYPE[T.Hail]: 125.42178592243219
# VIF: EVENT_TYPE[T.Heat]: 20.628872087239458
# VIF: EVENT_TYPE[T.Heavy Rain]: 15.694569216455905
# VIF: EVENT_TYPE[T.Heavy Snow]: 40.50684749873572
# VIF: EVENT_TYPE[T.High Surf]: 6.062614060940351
# VIF: EVENT_TYPE[T.High Wind]: 75.20712016266317
# VIF: EVENT_TYPE[T.Hurricane]: 1.2754222655104408
# VIF: EVENT_TYPE[T.Ice Storm]: 4.135513906291466
# VIF: EVENT_TYPE[T.Lake-Effect Snow]: 3.5467083082564086
# VIF: EVENT_TYPE[T.Lakeshore Flood]: 2.607010463679314
# VIF: EVENT_TYPE[T.Lightning]: 12.053594168725542
# VIF: EVENT_TYPE[T.Rip Current]: 8.410311370682228
# VIF: EVENT_TYPE[T.Seiche]: 1.1109906415206467
# VIF: EVENT_TYPE[T.Sleet]: 1.259001640887042
# VIF: EVENT_TYPE[T.Sneakerwave]: 1.2035928796982507
# VIF: EVENT_TYPE[T.Storm Surge/Tide]: 1.5547177387663742
# VIF: EVENT_TYPE[T.Strong Wind]: 18.38083615771226
# VIF: EVENT_TYPE[T.Thunderstorm Wind]: 183.64276650073217
# VIF: EVENT_TYPE[T.Tornado]: 26.28046159694271
# VIF: EVENT_TYPE[T.Tropical Depression]: 1.4068487254236772
# VIF: EVENT_TYPE[T.Tropical Storm]: 3.638721762115962
# VIF: EVENT_TYPE[T.Tsunami]: 1.0924938744559625
# VIF: EVENT_TYPE[T.Volcanic Ashfall]: 1.2219571891232037
# VIF: EVENT_TYPE[T.Wildfire]: 29.676890736676903
# VIF: EVENT_TYPE[T.Winter Storm]: 38.973114464592584
# VIF: EVENT_TYPE[T.Winter Weather]: 56.8281238705693
# VIF: INJURIES_DIRECT: 1.0219920497734494
# VIF: INJURIES_INDIRECT: 1.075752820936885
# VIF: DEATHS_DIRECT: 1.0472250129058247
# VIF: DEATHS_INDIRECT: 1.1007911469020653
# Question 3
# VIF: EVENT_TYPE[T.Avalanche]: 3.070603413485773
# VIF: EVENT_TYPE[T.Blizzard]: 8.856918339102132
# VIF: EVENT_TYPE[T.Coastal Flood]: 7.543749070918439
# VIF: EVENT_TYPE[T.Cold/Wind Chill]: 7.747268398897487
# VIF: EVENT_TYPE[T.Debris Flow]: 4.153848387864669
# VIF: EVENT_TYPE[T.Dense Fog]: 15.522447979314652
# VIF: EVENT_TYPE[T.Dense Smoke]: 1.3513877092908162
# VIF: EVENT_TYPE[T.Drought]: 46.67137702765306
# VIF: EVENT_TYPE[T.Dust Devil]: 1.55606222644243
# VIF: EVENT_TYPE[T.Dust Storm]: 3.805794079783224
# VIF: EVENT_TYPE[T.Excessive Heat]: 15.731828371762097
# VIF: EVENT_TYPE[T.Extreme Cold/Wind Chill]: 8.838704573527124
# VIF: EVENT_TYPE[T.Flash Flood]: 70.8167107104026
# VIF: EVENT_TYPE[T.Flood]: 59.318598368572786
# VIF: EVENT_TYPE[T.Freezing Fog]: 1.5380000589995382
# VIF: EVENT_TYPE[T.Frost/Freeze]: 12.685150465508615
# VIF: EVENT_TYPE[T.Funnel Cloud]: 10.820100083458625
# VIF: EVENT_TYPE[T.Hail]: 125.42178592243219
# VIF: EVENT_TYPE[T.Heat]: 20.628872087239458
# VIF: EVENT_TYPE[T.Heavy Rain]: 15.694569216455905
# VIF: EVENT_TYPE[T.Heavy Snow]: 40.50684749873572
# VIF: EVENT_TYPE[T.High Surf]: 6.062614060940351
# VIF: EVENT_TYPE[T.High Wind]: 75.20712016266317
# VIF: EVENT_TYPE[T.Hurricane]: 1.2754222655104408
# VIF: EVENT_TYPE[T.Ice Storm]: 4.135513906291466
# VIF: EVENT_TYPE[T.Lake-Effect Snow]: 3.5467083082564086
# VIF: EVENT_TYPE[T.Lakeshore Flood]: 2.607010463679314
# VIF: EVENT_TYPE[T.Lightning]: 12.053594168725542
# VIF: EVENT_TYPE[T.Rip Current]: 8.410311370682228
# VIF: EVENT_TYPE[T.Seiche]: 1.1109906415206467
# VIF: EVENT_TYPE[T.Sleet]: 1.259001640887042
# VIF: EVENT_TYPE[T.Sneakerwave]: 1.2035928796982507
# VIF: EVENT_TYPE[T.Storm Surge/Tide]: 1.5547177387663742
# VIF: EVENT_TYPE[T.Strong Wind]: 18.38083615771226
# VIF: EVENT_TYPE[T.Thunderstorm Wind]: 183.64276650073217
# VIF: EVENT_TYPE[T.Tornado]: 26.28046159694271
# VIF: EVENT_TYPE[T.Tropical Depression]: 1.4068487254236772
# VIF: EVENT_TYPE[T.Tropical Storm]: 3.638721762115962
# VIF: EVENT_TYPE[T.Tsunami]: 1.0924938744559625
# VIF: EVENT_TYPE[T.Volcanic Ashfall]: 1.2219571891232037
# VIF: EVENT_TYPE[T.Wildfire]: 29.676890736676903
# VIF: EVENT_TYPE[T.Winter Storm]: 38.973114464592584
# VIF: EVENT_TYPE[T.Winter Weather]: 56.8281238705693
# VIF: INJURIES_DIRECT: 1.0219920497734494
# VIF: INJURIES_INDIRECT: 1.075752820936885
# VIF: DEATHS_DIRECT: 1.0472250129058247
# VIF: DEATHS_INDIRECT: 1.1007911469020653
# Question 4
# VIF: EVENT_TYPE[T.Avalanche]: 3.070603413485773
# VIF: EVENT_TYPE[T.Blizzard]: 8.856918339102132
# VIF: EVENT_TYPE[T.Coastal Flood]: 7.543749070918439
# VIF: EVENT_TYPE[T.Cold/Wind Chill]: 7.747268398897487
# VIF: EVENT_TYPE[T.Debris Flow]: 4.153848387864669
# VIF: EVENT_TYPE[T.Dense Fog]: 15.522447979314652
# VIF: EVENT_TYPE[T.Dense Smoke]: 1.3513877092908162
# VIF: EVENT_TYPE[T.Drought]: 46.67137702765306
# VIF: EVENT_TYPE[T.Dust Devil]: 1.55606222644243
# VIF: EVENT_TYPE[T.Dust Storm]: 3.805794079783224
# VIF: EVENT_TYPE[T.Excessive Heat]: 15.731828371762097
# VIF: EVENT_TYPE[T.Extreme Cold/Wind Chill]: 8.838704573527124
# VIF: EVENT_TYPE[T.Flash Flood]: 70.8167107104026
# VIF: EVENT_TYPE[T.Flood]: 59.318598368572786
# VIF: EVENT_TYPE[T.Freezing Fog]: 1.5380000589995382
# VIF: EVENT_TYPE[T.Frost/Freeze]: 12.685150465508615
# VIF: EVENT_TYPE[T.Funnel Cloud]: 10.820100083458625
# VIF: EVENT_TYPE[T.Hail]: 125.42178592243219
# VIF: EVENT_TYPE[T.Heat]: 20.628872087239458
# VIF: EVENT_TYPE[T.Heavy Rain]: 15.694569216455905
# VIF: EVENT_TYPE[T.Heavy Snow]: 40.50684749873572
# VIF: EVENT_TYPE[T.High Surf]: 6.062614060940351
# VIF: EVENT_TYPE[T.High Wind]: 75.20712016266317
# VIF: EVENT_TYPE[T.Hurricane]: 1.2754222655104408
# VIF: EVENT_TYPE[T.Ice Storm]: 4.135513906291466
# VIF: EVENT_TYPE[T.Lake-Effect Snow]: 3.5467083082564086
# VIF: EVENT_TYPE[T.Lakeshore Flood]: 2.607010463679314
# VIF: EVENT_TYPE[T.Lightning]: 12.053594168725542
# VIF: EVENT_TYPE[T.Rip Current]: 8.410311370682228
# VIF: EVENT_TYPE[T.Seiche]: 1.1109906415206467
# VIF: EVENT_TYPE[T.Sleet]: 1.259001640887042
# VIF: EVENT_TYPE[T.Sneakerwave]: 1.2035928796982507
# VIF: EVENT_TYPE[T.Storm Surge/Tide]: 1.5547177387663742
# VIF: EVENT_TYPE[T.Strong Wind]: 18.38083615771226
# VIF: EVENT_TYPE[T.Thunderstorm Wind]: 183.64276650073217
# VIF: EVENT_TYPE[T.Tornado]: 26.28046159694271
# VIF: EVENT_TYPE[T.Tropical Depression]: 1.4068487254236772
# VIF: EVENT_TYPE[T.Tropical Storm]: 3.638721762115962
# VIF: EVENT_TYPE[T.Tsunami]: 1.0924938744559625
# VIF: EVENT_TYPE[T.Volcanic Ashfall]: 1.2219571891232037
# VIF: EVENT_TYPE[T.Wildfire]: 29.676890736676903
# VIF: EVENT_TYPE[T.Winter Storm]: 38.973114464592584
# VIF: EVENT_TYPE[T.Winter Weather]: 56.8281238705693
# VIF: INJURIES_DIRECT: 1.0219920497734494
# VIF: INJURIES_INDIRECT: 1.075752820936885
# VIF: DEATHS_DIRECT: 1.0472250129058247
# VIF: DEATHS_INDIRECT: 1.1007911469020653
# Question 5
# VIF: EVENT_TYPE[T.Avalanche]: 3.070603413485773
# VIF: EVENT_TYPE[T.Blizzard]: 8.856918339102132
# VIF: EVENT_TYPE[T.Coastal Flood]: 7.543749070918439
# VIF: EVENT_TYPE[T.Cold/Wind Chill]: 7.747268398897487
# VIF: EVENT_TYPE[T.Debris Flow]: 4.153848387864669
# VIF: EVENT_TYPE[T.Dense Fog]: 15.522447979314652
# VIF: EVENT_TYPE[T.Dense Smoke]: 1.3513877092908162
# VIF: EVENT_TYPE[T.Drought]: 46.67137702765306
# VIF: EVENT_TYPE[T.Dust Devil]: 1.55606222644243
# VIF: EVENT_TYPE[T.Dust Storm]: 3.805794079783224
# VIF: EVENT_TYPE[T.Excessive Heat]: 15.731828371762097
# VIF: EVENT_TYPE[T.Extreme Cold/Wind Chill]: 8.838704573527124
# VIF: EVENT_TYPE[T.Flash Flood]: 70.8167107104026
# VIF: EVENT_TYPE[T.Flood]: 59.318598368572786
# VIF: EVENT_TYPE[T.Freezing Fog]: 1.5380000589995382
# VIF: EVENT_TYPE[T.Frost/Freeze]: 12.685150465508615
# VIF: EVENT_TYPE[T.Funnel Cloud]: 10.820100083458625
# VIF: EVENT_TYPE[T.Hail]: 125.42178592243219
# VIF: EVENT_TYPE[T.Heat]: 20.628872087239458
# VIF: EVENT_TYPE[T.Heavy Rain]: 15.694569216455905
# VIF: EVENT_TYPE[T.Heavy Snow]: 40.50684749873572
# VIF: EVENT_TYPE[T.High Surf]: 6.062614060940351
# VIF: EVENT_TYPE[T.High Wind]: 75.20712016266317
# VIF: EVENT_TYPE[T.Hurricane]: 1.2754222655104408
# VIF: EVENT_TYPE[T.Ice Storm]: 4.135513906291466
# VIF: EVENT_TYPE[T.Lake-Effect Snow]: 3.5467083082564086
# VIF: EVENT_TYPE[T.Lakeshore Flood]: 2.607010463679314
# VIF: EVENT_TYPE[T.Lightning]: 12.053594168725542
# VIF: EVENT_TYPE[T.Rip Current]: 8.410311370682228
# VIF: EVENT_TYPE[T.Seiche]: 1.1109906415206467
# VIF: EVENT_TYPE[T.Sleet]: 1.259001640887042
# VIF: EVENT_TYPE[T.Sneakerwave]: 1.2035928796982507
# VIF: EVENT_TYPE[T.Storm Surge/Tide]: 1.5547177387663742
# VIF: EVENT_TYPE[T.Strong Wind]: 18.38083615771226
# VIF: EVENT_TYPE[T.Thunderstorm Wind]: 183.64276650073217
# VIF: EVENT_TYPE[T.Tornado]: 26.28046159694271
# VIF: EVENT_TYPE[T.Tropical Depression]: 1.4068487254236772
# VIF: EVENT_TYPE[T.Tropical Storm]: 3.638721762115962
# VIF: EVENT_TYPE[T.Tsunami]: 1.0924938744559625
# VIF: EVENT_TYPE[T.Volcanic Ashfall]: 1.2219571891232037
# VIF: EVENT_TYPE[T.Wildfire]: 29.676890736676903
# VIF: EVENT_TYPE[T.Winter Storm]: 38.973114464592584
# VIF: EVENT_TYPE[T.Winter Weather]: 56.8281238705693
# VIF: INJURIES_DIRECT: 1.0219920497734494
# VIF: INJURIES_INDIRECT: 1.075752820936885
# VIF: DEATHS_DIRECT: 1.0472250129058247
# VIF: DEATHS_INDIRECT: 1.1007911469020653

# %% [markdown]
# ### Shapiro-Wilk Test

# %%
q_num = 1
for model in event_models:
    print(f'Question {q_num}')
    shapiro_test = stats.shapiro(model.resid)
    q_num += 1
    print(shapiro_test)
# Out:
# Question 1
# ShapiroResult(statistic=0.9957625727781415, pvalue=3.248175247738438e-35)
# Question 2
# ShapiroResult(statistic=0.9924225189984102, pvalue=1.7702897072335268e-44)
# Question 3
# ShapiroResult(statistic=0.9908759435716618, pvalue=1.1228416095767614e-47)
# Question 4
# ShapiroResult(statistic=0.9857982720239582, pvalue=9.312427579488783e-56)
# Question 5
# ShapiroResult(statistic=0.9928935501055185, pvalue=2.1194853597311297e-43)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 55339.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# ### Analysis of Variance (ANOVA) for Climate Opinion Model
#
# #### State & Year Covariates
# Inline with previous analysis, we construct a simple linear regression model which predicts the percentage of support of climate opinon questions given the count of weather effects and the category of question. We want to test whether the inclusion of varaibles like the `STATE` and `YEAR` significantly improves the model fit. To do this, we will carry out an analysis of variance. We define the larger and smaller models to be as follows:
#
# $$
# \begin{aligned}\\
# \text{Small model:} \quad \text{percent support}_i &= \beta_0 + \beta_1(\text{count of weather events}) + \beta_2(\text{question}) + \epsilon_i \\ \\
# \text{Large model:} \quad \text{percent support}_i &= \beta_0 + \beta_1(\text{count of weather events}) + \beta_2(\text{question}) + \beta_3(\text{year}) + \beta_4(\text{state}) + \epsilon_i \\ \\
# \end{aligned}
# $$
#
# and our test statistic, $\hat F$, to be:
#
# $$
# \hat F = {\frac{\text{SS}_{Reg}(\text{Small Model}) - \text{SS}_{Reg}(\text{Big Model})}{\Delta \text{df}} \Bigg / {\frac{\text{SS}_{Res}(\text{Big Model})}{\text{df}_{Res}(\text{Big Model})}}} \\
# $$
#
# We carry out this test at a significance level of, $\alpha = 0.01$.

# %%
small_formula = f'percentage ~ COUNT + varname'
big_formula = f'percentage ~ '+ '+'.join(event_count_merged.columns.difference(['percentage']))

# %%
small_model = smf.ols(small_formula, data=event_count_merged).fit()
big_model = smf.ols(big_formula, data=event_count_merged).fit()

anova_table = sm.stats.anova_lm(small_model, big_model)
anova_table
# Out:
#    df_resid           ssr  df_diff       ss_diff          F  Pr(>F)
# 0    1494.0  40605.368203      0.0           NaN        NaN     NaN
# 1    1444.0  11541.798851     50.0  29063.569352  72.723143     0.0

# %% [markdown]
# Looking at the ANOVA table, the pvalue of our test is calculated to be:

# %%
anova_table['Pr(>F)'].values[1]
# Out:
# 0.0

# %% [markdown]
# At a significance level of $\alpha = 0.01$ we come to conclusion that we reject the null hypothesis that the inclusion of the defined additional covariates does not improve model fit.**Hence, there is sufficient evidence to conclude that the addition of the covariates `YEAR` and `STATE` improves the model fit for predicting the response variable of `percentage`.**
#
# <br><br>

# %% [markdown]
# #### Weather Event Type Covariates
#
# Alternatively we can investigate the relationship of extreme weather event types and injuries in predicting the percentage of support of our five climate questions. We construct a similar model to the previous regression models which predicts the percentage of support of climate opinon questions given the question, state, and year. We want to test whether the inclusion of varaibles like the `EVENT_TYPE`, `INJURIES DIRECT`, and `DEATHS_DIRECT` significantly improve the model fit. To do this, we will carry out ANOVA. We define the larger and smaller models to be as follows:
#
# $$
# \begin{aligned}\\
# \text{Small model:} \quad \text{percent support}_i &= \beta_0 + \beta_1(\text{question}) + \beta_2(\text{year}) + \beta_3(\text{state}) + \epsilon_i \\ \\
# \text{Large model:} \quad \text{percent support}_i &= \beta_0 + \beta_1(\text{question}) + \beta_2(\text{year}) + \beta_3(\text{state}) + \beta_4(\text{event type}) + \beta_5(\text{direct injuries}) + \beta_6(\text{direct deaths}) + \epsilon_i \\ \\
# \end{aligned}
# $$
#
# We carry out this test at a significance level of, $\alpha = 0.01$.

# %%
small_formula2 = f'percentage ~ varname + YEAR + STATE'
big_formula2 = f'percentage ~ varname + YEAR + STATE + EVENT_TYPE + INJURIES_DIRECT + DEATHS_DIRECT'

# %%
small_model2 = smf.ols(small_formula2, data=events_df_merged).fit()
big_model2 = smf.ols(big_formula2, data=events_df_merged).fit()

anova_table2 = sm.stats.anova_lm(small_model2, big_model2)
anova_table2
# Out:
#    df_resid           ssr  df_diff     ss_diff         F        Pr(>F)
# 0  276640.0  2.147936e+06      0.0         NaN       NaN           NaN
# 1  276595.0  2.147072e+06     45.0  863.173955  2.471061  1.593744e-07

# %% [markdown]
# Looking at the ANOVA table, the pvalue of our test is calculated to be:

# %%
anova_table['Pr(>F)'].values[1]
# Out:
# 0.0

# %% [markdown]
# At a significance level of $\alpha = 0.01$ we come to conclusion that we reject the null hypothesis that the inclusion of the defined additional covariates does not improve model fit.**Hence, there is sufficient evidence to conclude that the addition of the covariates  `EVENT_TYPE`, `INJURIES DIRECT`, and `DEATHS_DIRECT` improves the model fit for predicting the response variable of `percentage`.**
#
# <br><br>

# %% [markdown]
# ## Hypotheis Testing

# %% [markdown]
# Assumption: Since our data is slightly but not incredibly skewed and we are taking a specific subset of our total data (which is a survey not a population), we can perform a t test to see if the states we deemed most impacted by climate change feel more strongly on the topic in the direction of more climate action.

# %% [markdown]
# $H_0$: $\hat \mu = \mu_0$ (i.e. sample mean is equal to the total population for given question)\
# $H_0$: $\hat \mu \gt \mu_0$ (i.e. sample mean is greater than total population for given question)

# %%
def t_test(question):
    yale_climate_23_gov = yale_climate[(yale_climate['year']==2023) & (yale_climate['varname']==question)]
    nat_avg = yale_climate_23_gov['percentage'].sum() / yale_climate_23_gov.shape[0]
    top5_df = yale_climate_23_gov[yale_climate_23_gov['geoname'].isin(['TEXAS', 'ALASKA', 'OKLAHOMA', 'NEVADA', 'FLORIDA'])]
    merged_states2 = merged_states.sort_values('count_difference', ascending=False)
    states = merged_states2['STATE'][0:5]
    mean_gov_states = 0.0
    for i in states:
        mean_gov_states += yale_climate_23_gov[yale_climate_23_gov['geoname']==i]['percentage'].iloc[0]
    mean_gov_states = mean_gov_states/5
    Xbar = mean_gov_states
    mu = nat_avg
    stdev = np.std(yale_climate_23_gov['percentage'])
    stdev_hat = top5_df['percentage'].std()*np.sqrt(5)/np.sqrt(4) #std uses denominator of sqrt(n), we need sqrt(n-1)
    n = 5
    t_n = (Xbar-mu)/(stdev_hat/np.sqrt(n))
    pval = 1 - t.cdf(t_n, n-1)
    print('Question topic: ' + question) 
    print('\nXbar (top 5 mean): ' + str(Xbar))
    print('Mu (National Avg): '+ str(nat_avg))
    print('T stat: '+ str(t_n))
    print('p value: ' + str(pval))
    if(pval>0.05):
        print('\np-value high, fail to reject null hypothesis: no significant relation between weather events and this question')
    else:
        print('\np-value low, reject null hypothesis')
    return [t_n, stdev_hat, mu, stdev]

# %%
def t_hist(question):
    datas = t_test(question)
    plt.hist(yale_climate[(yale_climate['year']==2023) & (yale_climate['varname']==question)]['percentage'], density=True)
    x = np.linspace(20, 90, 1000)
    scale = datas[3]
    y = t.pdf((x - datas[2]) / scale, 50) * (1 / scale)
    plt.plot(x, y, 'r-', lw=2, label=f't-distribution centered at {datas[2]} (df=50)')
    plt.vlines(datas[0] * datas[1]/np.sqrt(5) + datas[2], 0, 0.15, color='red', linestyles='--', lw=2)

# %%
t_hist(research_questions[0])
# Out:
# Question topic: affectweather
#
# Xbar (top 5 mean): 58.936
# Mu (National Avg): 60.64098039215686
# T stat: -0.7962607043761704
# p value: 0.7647673168666013
#
# p-value high, fail to reject null hypothesis: no significant relation between weather events and this question

# %% [markdown]
# Our subset mean is less than the population mean so it's clear that a t test would not result in rejecting the null hypothesis for the question "does climate change affect weather?"

# %%
t_hist(research_questions[1])
# Out:
# Question topic: worried
#
# Xbar (top 5 mean): 61.498000000000005
# Mu (National Avg): 61.73
# T stat: -0.12159907845308786
# p value: 0.5454597283614094
#
# p-value high, fail to reject null hypothesis: no significant relation between weather events and this question

# %% [markdown]
# Our subset mean is close to the population mean so our t test is not significant enough to reject the null hypothesis for the question "are you worried about climate change?"

# %%
t_hist(research_questions[2])
# Out:
# Question topic: regulate
#
# Xbar (top 5 mean): 71.28
# Mu (National Avg): 72.60960784313725
# T stat: -0.9621838232305864
# p value: 0.8047775678883733
#
# p-value high, fail to reject null hypothesis: no significant relation between weather events and this question

# %% [markdown]
# Our subset mean is less than the population mean so it's clear that a t test would not result in rejecting the null hypothesis for the question "Should we regulate emissions?"

# %%
t_hist(research_questions[3])
# Out:
# Question topic: governor
#
# Xbar (top 5 mean): 53.164
# Mu (National Avg): 52.63529411764705
# T stat: 0.24933527506543318
# p value: 0.4076908250439011
#
# p-value high, fail to reject null hypothesis: no significant relation between weather events and this question

# %% [markdown]
# Our subset mean is slightly more than the mean of the data, but not significant enough to reject the null hypothesis for "the governor should do more about climate change".

# %%
t_hist(research_questions[4])
# Out:
# Question topic: discuss
#
# Xbar (top 5 mean): 34.028000000000006
# Mu (National Avg): 34.98196078431373
# T stat: -0.5297632451883565
# p value: 0.687841659137356
#
# p-value high, fail to reject null hypothesis: no significant relation between weather events and this question

# %% [markdown]
# Our subset mean is less than the population mean so it's clear that a t test would not result in rejecting the null hypothesis for the question "do you often talk about climate change?"

# %% [markdown]
# # Discussion and Conclusion

# %% [markdown]
# > How do you interpret the results from these analyses?
# > What are some potential limitations and shortcoming of your analyses?

# %%
...
# Out:
# Ellipsis
